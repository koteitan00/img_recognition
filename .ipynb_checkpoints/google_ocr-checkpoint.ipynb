# %% [markdown]
# ## Start Up

# %%
print(torch.__version__, torch.cuda.is_available())
# Out:
# 2.1.0+cu118 True

# %%
import io
import os
import os.path
import re
import matplotlib.pyplot as plt
import cv2
import csv
import numpy as np
from PIL import Image
from io import BytesIO
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload
from googleapiclient.http import MediaIoBaseDownload
import torch
import torchvision

SCOPES = ['https://www.googleapis.com/auth/drive.file']
MIME_TYPE = 'application/vnd.google-apps.document'
APPLICATION_NAME = 'ipa-google-drive-api-client'

# %%
cd "C:\Users\covid\text_recognition"
# Out:
# C:\Users\covid\text_recognition

# %%
def get_service():

    # credentialの取得
    creds = None
    if os.path.exists('token.json'):
        creds = Credentials.from_authorized_user_file('token.json', SCOPES)
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'google-drive-api.json', SCOPES)
            creds = flow.run_local_server(port=0)
        with open('token.json', 'w') as token:
            token.write(creds.to_json())
        
    # serviceの取得
    service = build('drive', 'v3', credentials=creds) 
    
    return service

def read_ocr(service, input_file, lang='jp'):
    # ファイルのアップロード

    # ローカルファイルの定義
    media_body = MediaFileUpload(input_file, mimetype=MIME_TYPE, resumable=True)

    # Google Drive上のファイル名
    newfile = 'output.pdf'

    body = {
        'name': newfile,
        'mimeType': MIME_TYPE
    }

    # 　creat関数でファイルアップロード実行
    # 同時にOCR読み取りも行う
    output = service.files().create(
        body=body,
        media_body=media_body,
        # ここで読み込み先言語の指定を行う
        ocrLanguage=lang,
    ).execute()

    # テキストファイルのダウンロード

    # リクエストオブジェクト生成
    request = service.files().export_media(
        fileId=output['id'],
        mimeType="text/plain"
    )
    output_path = 'output.txt'

    with open(output_path, 'a') as f:
        fh = io.FileIO(output_path, "wb")
        downloader = MediaIoBaseDownload(fh, request)
        done = False
        while done is False:
            status, done = downloader.next_chunk()

        service.files().delete(fileId=output['id']).execute()
    
        # テキストの取得
    with open(output_path, 'r', encoding='utf-8') as f:
        lines = f.readlines()

    # 読み取り結果のリストを返す
    return lines[1:]


service = get_service()
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=177107319826-i8oj1jnq3najvtvm0prpb18ncuipamef.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A54921%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.file&state=xu8WZYBW1NaZm8XWShPh0a53Aid1y4&access_type=offline

# %%
def process_text_file(text_file):
    output_dir = "C:/Users/covid/text_recognition/output"
    if os.path.exists(output_dir):
        file_list = [f for f in os.listdir(output_dir) if os.path.isfile(os.path.join(output_dir, f))]
        for file_name in file_list:
            file_path = os.path.join(output_dir, file_name)
            os.remove(file_path)
    else:
        os.makedirs(output_dir)

    with open(text_file, 'r') as file:
        lines = file.readlines()

        lines = sorted(lines, key=lambda line: float(line.split()[1]))

        for i, line in enumerate(lines):
            line = line.strip()
            values = line.split()

            if len(values) == 5:
                object_class = values[0]
                a = float(values[1])
                b = float(values[2])
                c = float(values[3])
                d = float(values[4])

                # Calculate coordinates and dimensions
                x_center = int(wid * a)
                y_center = int(hei * b)
                width = int(wid * c)
                height = int(hei * d)

                x_min = x_center - width // 2
                y_min = y_center - height // 2
                x_max = x_center + width // 2
                y_max = y_center + height // 2

                output_filename = os.path.join(output_dir, f'book{i+1}.jpg')
                index = 1
                while os.path.exists(output_filename):
                    output_filename = os.path.join(output_dir, f'book{i+1}_{index}.jpg')
                    index += 1

                # Crop and save the image
                cropped = image.crop((x_min, y_min, x_max, y_max))
                cropped.save(output_filename)

# %%
# !pip install inference-sdk
# Out:
# Collecting inference-sdk
#   Using cached inference_sdk-0.13.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: requests>=2.0.0 in c:\users\covid\anaconda3\lib\site-packages (from inference-sdk) (2.28.1)
# Collecting dataclasses-json>=0.6.0 (from inference-sdk)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting opencv-python>=4.8.0.0 (from inference-sdk)
#   Downloading opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\covid\anaconda3\lib\site-packages (from inference-sdk) (9.4.0)
# Collecting supervision<1.0.0,>=0.20.0 (from inference-sdk)
#   Using cached supervision-0.21.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<=1.26.4 in c:\users\covid\anaconda3\lib\site-packages (from inference-sdk) (1.23.5)
# Collecting aiohttp>=3.9.0 (from inference-sdk)
#   Using cached aiohttp-3.9.5-cp310-cp310-win_amd64.whl.metadata (7.7 kB)
# Collecting backoff>=2.2.0 (from inference-sdk)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting aioresponses>=0.7.6 (from inference-sdk)
#   Using cached aioresponses-0.7.6-py2.py3-none-any.whl.metadata (9.8 kB)
# Collecting py-cpuinfo>=9.0.0 (from inference-sdk)
#   Using cached py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Collecting aiosignal>=1.1.2 (from aiohttp>=3.9.0->inference-sdk)
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\covid\anaconda3\lib\site-packages (from aiohttp>=3.9.0->inference-sdk) (22.1.0)
# Collecting frozenlist>=1.1.1 (from aiohttp>=3.9.0->inference-sdk)
#   Using cached frozenlist-1.4.1-cp310-cp310-win_amd64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp>=3.9.0->inference-sdk)
#   Using cached multidict-6.0.5-cp310-cp310-win_amd64.whl.metadata (4.3 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp>=3.9.0->inference-sdk)
#   Using cached yarl-1.9.4-cp310-cp310-win_amd64.whl.metadata (32 kB)
# Collecting async-timeout<5.0,>=4.0 (from aiohttp>=3.9.0->inference-sdk)
#   Using cached async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json>=0.6.0->inference-sdk)
#   Using cached marshmallow-3.21.3-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\covid\anaconda3\lib\site-packages (from dataclasses-json>=0.6.0->inference-sdk) (0.9.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\covid\anaconda3\lib\site-packages (from requests>=2.0.0->inference-sdk) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\covid\anaconda3\lib\site-packages (from requests>=2.0.0->inference-sdk) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\covid\anaconda3\lib\site-packages (from requests>=2.0.0->inference-sdk) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\covid\anaconda3\lib\site-packages (from requests>=2.0.0->inference-sdk) (2023.7.22)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in c:\users\covid\anaconda3\lib\site-packages (from supervision<1.0.0,>=0.20.0->inference-sdk) (0.7.1)
# Requirement already satisfied: matplotlib>=3.6.0 in c:\users\covid\anaconda3\lib\site-packages (from supervision<1.0.0,>=0.20.0->inference-sdk) (3.7.0)
# Requirement already satisfied: opencv-python-headless>=4.5.5.64 in c:\users\covid\anaconda3\lib\site-packages (from supervision<1.0.0,>=0.20.0->inference-sdk) (4.8.0.74)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\covid\anaconda3\lib\site-packages (from supervision<1.0.0,>=0.20.0->inference-sdk) (6.0)
# Requirement already satisfied: scipy<2.0.0,>=1.10.0 in c:\users\covid\anaconda3\lib\site-packages (from supervision<1.0.0,>=0.20.0->inference-sdk) (1.10.0)
# Requirement already satisfied: packaging>=17.0 in c:\users\covid\anaconda3\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json>=0.6.0->inference-sdk) (22.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\covid\anaconda3\lib\site-packages (from matplotlib>=3.6.0->supervision<1.0.0,>=0.20.0->inference-sdk) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\covid\anaconda3\lib\site-packages (from matplotlib>=3.6.0->supervision<1.0.0,>=0.20.0->inference-sdk) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\covid\anaconda3\lib\site-packages (from matplotlib>=3.6.0->supervision<1.0.0,>=0.20.0->inference-sdk) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\covid\anaconda3\lib\site-packages (from matplotlib>=3.6.0->supervision<1.0.0,>=0.20.0->inference-sdk) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\covid\anaconda3\lib\site-packages (from matplotlib>=3.6.0->supervision<1.0.0,>=0.20.0->inference-sdk) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\covid\anaconda3\lib\site-packages (from matplotlib>=3.6.0->supervision<1.0.0,>=0.20.0->inference-sdk) (2.8.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\covid\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json>=0.6.0->inference-sdk) (0.4.3)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\covid\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json>=0.6.0->inference-sdk) (4.4.0)
# Requirement already satisfied: six in c:\users\covid\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=3.6.0->supervision<1.0.0,>=0.20.0->inference-sdk) (1.16.0)
# Using cached inference_sdk-0.13.0-py3-none-any.whl (30 kB)
# Using cached aiohttp-3.9.5-cp310-cp310-win_amd64.whl (370 kB)
# Using cached aioresponses-0.7.6-py2.py3-none-any.whl (11 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    - -------------------------------------- 1.2/38.8 MB 25.3 MB/s eta 0:00:02
#    --- ------------------------------------ 3.5/38.8 MB 36.8 MB/s eta 0:00:01
#    ------- -------------------------------- 7.0/38.8 MB 56.2 MB/s eta 0:00:01
#    ----------- ---------------------------- 11.6/38.8 MB 81.8 MB/s eta 0:00:01
#    --------------- ------------------------ 15.4/38.8 MB 93.0 MB/s eta 0:00:01
#    -------------------- ------------------- 20.2/38.8 MB 93.0 MB/s eta 0:00:01
#    -------------------------- ------------- 25.5/38.8 MB 110.0 MB/s eta 0:00:01
#    -------------------------------- ------- 31.2/38.8 MB 110.0 MB/s eta 0:00:01
#    ------------------------------------ --- 35.4/38.8 MB 108.8 MB/s eta 0:00:01
#    ---------------------------------------  38.8/38.8 MB 110.0 MB/s eta 0:00:01
#    ---------------------------------------- 38.8/38.8 MB 73.0 MB/s eta 0:00:00
# Using cached py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Using cached supervision-0.21.0-py3-none-any.whl (123 kB)
# Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Using cached async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Using cached frozenlist-1.4.1-cp310-cp310-win_amd64.whl (50 kB)
# Using cached marshmallow-3.21.3-py3-none-any.whl (49 kB)
# Using cached multidict-6.0.5-cp310-cp310-win_amd64.whl (28 kB)
# Using cached yarl-1.9.4-cp310-cp310-win_amd64.whl (76 kB)
# Installing collected packages: py-cpuinfo, opencv-python, multidict, marshmallow, frozenlist, backoff, async-timeout, yarl, dataclasses-json, aiosignal, supervision, aiohttp, aioresponses, inference-sdk
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.7.0.72
#     Uninstalling opencv-python-4.7.0.72:
#       Successfully uninstalled opencv-python-4.7.0.72
# Successfully installed aiohttp-3.9.5 aioresponses-0.7.6 aiosignal-1.3.1 async-timeout-4.0.3 backoff-2.2.1 dataclasses-json-0.6.7 frozenlist-1.4.1 inference-sdk-0.13.0 marshmallow-3.21.3 multidict-6.0.5 opencv-python-4.10.0.84 py-cpuinfo-9.0.0 supervision-0.21.0 yarl-1.9.4
# [notice] A new release of pip is available: 23.3.1 -> 24.1.1
# [notice] To update, run: C:\Users\covid\anaconda3\python.exe -m pip install --upgrade pip

# %%
# !pip install -U roboflow
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-intel 2.14.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 4.21.2 which is incompatible.
#
# [notice] A new release of pip is available: 23.3.1 -> 24.1.1
# [notice] To update, run: C:\Users\covid\anaconda3\python.exe -m pip install --upgrade pip
# Requirement already satisfied: roboflow in c:\users\covid\anaconda3\lib\site-packages (1.1.29)
# Collecting roboflow
#   Using cached roboflow-1.1.34-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: certifi in c:\users\covid\anaconda3\lib\site-packages (from roboflow) (2023.7.22)
# Requirement already satisfied: chardet==4.0.0 in c:\users\covid\anaconda3\lib\site-packages (from roboflow) (4.0.0)
# Collecting idna==3.7 (from roboflow)
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in c:\users\covid\anaconda3\lib\site-packages (from roboflow) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\covid\anaconda3\lib\site-packages (from roboflow) (1.4.4)
# Requirement already satisfied: matplotlib in c:\users\covid\anaconda3\lib\site-packages (from roboflow) (3.7.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\covid\anaconda3\lib\site-packages (from roboflow) (1.23.5)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\covid\anaconda3\lib\site-packages (from roboflow) (9.4.0)
# Requirement already satisfied: python-dateutil in c:\users\covid\anaconda3\lib\site-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in c:\users\covid\anaconda3\lib\site-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in c:\users\covid\anaconda3\lib\site-packages (from roboflow) (2.28.1)
# Requirement already satisfied: six in c:\users\covid\anaconda3\lib\site-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in c:\users\covid\anaconda3\lib\site-packages (from roboflow) (1.26.14)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\covid\anaconda3\lib\site-packages (from roboflow) (4.64.1)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\covid\anaconda3\lib\site-packages (from roboflow) (6.0)
# Requirement already satisfied: requests-toolbelt in c:\users\covid\anaconda3\lib\site-packages (from roboflow) (0.9.1)
# Requirement already satisfied: python-magic in c:\users\covid\anaconda3\lib\site-packages (from roboflow) (0.4.27)
# Requirement already satisfied: colorama in c:\users\covid\anaconda3\lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\covid\anaconda3\lib\site-packages (from matplotlib->roboflow) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\covid\anaconda3\lib\site-packages (from matplotlib->roboflow) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\covid\anaconda3\lib\site-packages (from matplotlib->roboflow) (22.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\covid\anaconda3\lib\site-packages (from matplotlib->roboflow) (3.0.9)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\covid\anaconda3\lib\site-packages (from requests->roboflow) (2.0.4)
# Using cached roboflow-1.1.34-py3-none-any.whl (76 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
# Installing collected packages: opencv-python-headless, idna, roboflow
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.0.74
#     Uninstalling opencv-python-headless-4.8.0.74:
#       Successfully uninstalled opencv-python-headless-4.8.0.74
#   Attempting uninstall: idna
#     Found existing installation: idna 2.10
#     Uninstalling idna-2.10:
#       Successfully uninstalled idna-2.10
#   Attempting uninstall: roboflow
#     Found existing installation: roboflow 1.1.29
#     Uninstalling roboflow-1.1.29:
#       Successfully uninstalled roboflow-1.1.29
# Successfully installed idna-3.7 opencv-python-headless-4.10.0.84 roboflow-1.1.34

# %%
# !pip install inference
# Out:
# Collecting inference
#   Downloading inference-0.13.0-py3-none-any.whl.metadata (14 kB)
# Collecting APScheduler<=3.10.1 (from inference)
#   Downloading APScheduler-3.10.1-py3-none-any.whl.metadata (5.7 kB)
# Collecting cython<=3.0.0 (from inference)
#   Downloading Cython-3.0.0-cp310-cp310-win_amd64.whl.metadata (3.2 kB)
# Requirement already satisfied: python-dotenv<=2.0.0 in c:\users\covid\anaconda3\lib\site-packages (from inference) (1.0.1)
# Collecting fastapi<0.111,>=0.100 (from inference)
#   Downloading fastapi-0.110.3-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: numpy<=1.26.4 in c:\users\covid\anaconda3\lib\site-packages (from inference) (1.23.5)
# Collecting opencv-python<=4.8.0.76 (from inference)
#   Downloading opencv_python-4.8.0.76-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting piexif<=1.1.3 (from inference)
#   Downloading piexif-1.1.3-py2.py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: pillow<11.0 in c:\users\covid\anaconda3\lib\site-packages (from inference) (9.4.0)
# Collecting prometheus-fastapi-instrumentator<=6.0.0 (from inference)
#   Downloading prometheus_fastapi_instrumentator-6.0.0-py3-none-any.whl.metadata (13 kB)
# Collecting redis<6.0.0 (from inference)
#   Downloading redis-5.0.7-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: requests>=2.26.0 in c:\users\covid\anaconda3\lib\site-packages (from inference) (2.28.1)
# Collecting rich<=13.5.2 (from inference)
#   Downloading rich-13.5.2-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: supervision<1.0.0,>=0.20.0 in c:\users\covid\anaconda3\lib\site-packages (from inference) (0.21.0)
# Collecting pybase64<2.0.0 (from inference)
#   Downloading pybase64-1.3.2-cp310-cp310-win_amd64.whl.metadata (8.2 kB)
# Requirement already satisfied: scikit-image>=0.19.0 in c:\users\covid\anaconda3\lib\site-packages (from inference) (0.19.3)
# Collecting requests-toolbelt>=1.0.0 (from inference)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: wheel>=0.38.1 in c:\users\covid\anaconda3\lib\site-packages (from inference) (0.38.4)
# Requirement already satisfied: setuptools<70.0.0,>=65.5.1 in c:\users\covid\anaconda3\lib\site-packages (from inference) (65.6.3)
# Collecting pytest-asyncio<=0.21.1 (from inference)
#   Downloading pytest_asyncio-0.21.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting networkx>=3.1 (from inference)
#   Downloading networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Collecting pydantic~=2.6 (from inference)
#   Downloading pydantic-2.8.2-py3-none-any.whl.metadata (125 kB)
#      ---------------------------------------- 0.0/125.2 kB ? eta -:--:--
#      ---------------------------------------- 125.2/125.2 kB ? eta 0:00:00
# Collecting openai>=1.12.0 (from inference)
#   Downloading openai-1.35.10-py3-none-any.whl.metadata (21 kB)
# Collecting structlog>=24.1.0 (from inference)
#   Downloading structlog-24.2.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting zxing-cpp>=2.2.0 (from inference)
#   Downloading zxing_cpp-2.2.0-cp310-cp310-win_amd64.whl.metadata (1.9 kB)
# Collecting boto3<=1.34.123 (from inference)
#   Downloading boto3-1.34.123-py3-none-any.whl.metadata (6.6 kB)
# Collecting typing-extensions>=4.8.0 (from inference)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting pydot>=2.0.0 (from inference)
#   Downloading pydot-2.0.0-py3-none-any.whl.metadata (9.6 kB)
# Collecting shapely<2.1.0,>=2.0.0 (from inference)
#   Downloading shapely-2.0.4-cp310-cp310-win_amd64.whl.metadata (7.2 kB)
# Collecting onnxruntime<=1.15.1 (from inference)
#   Downloading onnxruntime-1.15.1-cp310-cp310-win_amd64.whl.metadata (4.1 kB)
# Collecting GPUtil==1.4.0 (from inference)
#   Downloading GPUtil-1.4.0.tar.gz (5.5 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting docker==6.1.3 (from inference)
#   Downloading docker-6.1.3-py3-none-any.whl.metadata (3.5 kB)
# Collecting typer==0.9.0 (from inference)
#   Downloading typer-0.9.0-py3-none-any.whl.metadata (14 kB)
# Collecting skypilot==0.5.0 (from skypilot[aws,gcp]==0.5.0->inference)
#   Downloading skypilot-0.5.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\covid\anaconda3\lib\site-packages (from inference) (6.0)
# Requirement already satisfied: tqdm>=4.0.0 in c:\users\covid\anaconda3\lib\site-packages (from inference) (4.64.1)
# Requirement already satisfied: py-cpuinfo>=9.0.0 in c:\users\covid\anaconda3\lib\site-packages (from inference) (9.0.0)
# Requirement already satisfied: aiohttp>=3.9.0 in c:\users\covid\anaconda3\lib\site-packages (from inference) (3.9.5)
# Requirement already satisfied: backoff>=2.2.0 in c:\users\covid\anaconda3\lib\site-packages (from inference) (2.2.1)
# Requirement already satisfied: dataclasses-json>=0.6.0 in c:\users\covid\anaconda3\lib\site-packages (from inference) (0.6.7)
# Requirement already satisfied: aioresponses>=0.7.6 in c:\users\covid\anaconda3\lib\site-packages (from inference) (0.7.6)
# Requirement already satisfied: packaging>=14.0 in c:\users\covid\anaconda3\lib\site-packages (from docker==6.1.3->inference) (22.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\covid\anaconda3\lib\site-packages (from docker==6.1.3->inference) (1.26.14)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\users\covid\anaconda3\lib\site-packages (from docker==6.1.3->inference) (0.58.0)
# Requirement already satisfied: pywin32>=304 in c:\users\covid\anaconda3\lib\site-packages (from docker==6.1.3->inference) (305.1)
# Requirement already satisfied: cachetools in c:\users\covid\anaconda3\lib\site-packages (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference) (5.3.1)
# Requirement already satisfied: click>=7.0 in c:\users\covid\anaconda3\lib\site-packages (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference) (8.0.4)
# Requirement already satisfied: colorama in c:\users\covid\anaconda3\lib\site-packages (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference) (0.4.6)
# Requirement already satisfied: cryptography in c:\users\covid\anaconda3\lib\site-packages (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference) (39.0.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\covid\anaconda3\lib\site-packages (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference) (3.1.2)
# Requirement already satisfied: jsonschema in c:\users\covid\anaconda3\lib\site-packages (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference) (4.17.3)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\covid\anaconda3\lib\site-packages (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference) (1.5.3)
# Collecting pendulum (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference)
#   Downloading pendulum-3.0.0-cp310-none-win_amd64.whl.metadata (7.0 kB)
# Collecting PrettyTable>=2.0.0 (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference)
#   Downloading prettytable-3.10.0-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: tabulate in c:\users\covid\anaconda3\lib\site-packages (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference) (0.8.10)
# Requirement already satisfied: filelock>=3.6.0 in c:\users\covid\anaconda3\lib\site-packages (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference) (3.9.0)
# Requirement already satisfied: psutil in c:\users\covid\anaconda3\lib\site-packages (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference) (5.9.0)
# Collecting pulp (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference)
#   Downloading PuLP-2.8.0-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: google-api-python-client>=2.69.0 in c:\users\covid\anaconda3\lib\site-packages (from skypilot[aws,gcp]==0.5.0->inference) (2.88.0)
# Collecting google-cloud-storage (from skypilot[aws,gcp]==0.5.0->inference)
#   Downloading google_cloud_storage-2.17.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting awscli>=1.27.10 (from skypilot[aws,gcp]==0.5.0->inference)
#   Downloading awscli-1.33.21-py3-none-any.whl.metadata (11 kB)
# Collecting botocore>=1.29.10 (from skypilot[aws,gcp]==0.5.0->inference)
#   Downloading botocore-1.34.139-py3-none-any.whl.metadata (5.7 kB)
# Collecting colorama (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference)
#   Downloading colorama-0.4.4-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\covid\anaconda3\lib\site-packages (from aiohttp>=3.9.0->inference) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\covid\anaconda3\lib\site-packages (from aiohttp>=3.9.0->inference) (22.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\covid\anaconda3\lib\site-packages (from aiohttp>=3.9.0->inference) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\covid\anaconda3\lib\site-packages (from aiohttp>=3.9.0->inference) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\covid\anaconda3\lib\site-packages (from aiohttp>=3.9.0->inference) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\covid\anaconda3\lib\site-packages (from aiohttp>=3.9.0->inference) (4.0.3)
# Requirement already satisfied: six>=1.4.0 in c:\users\covid\anaconda3\lib\site-packages (from APScheduler<=3.10.1->inference) (1.16.0)
# Requirement already satisfied: pytz in c:\users\covid\anaconda3\lib\site-packages (from APScheduler<=3.10.1->inference) (2022.7)
# Collecting tzlocal!=3.*,>=2.0 (from APScheduler<=3.10.1->inference)
#   Downloading tzlocal-5.2-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\covid\anaconda3\lib\site-packages (from boto3<=1.34.123->inference) (0.10.0)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3<=1.34.123->inference)
#   Downloading s3transfer-0.10.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\covid\anaconda3\lib\site-packages (from dataclasses-json>=0.6.0->inference) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\covid\anaconda3\lib\site-packages (from dataclasses-json>=0.6.0->inference) (0.9.0)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi<0.111,>=0.100->inference)
#   Downloading starlette-0.37.2-py3-none-any.whl.metadata (5.9 kB)
# Collecting coloredlogs (from onnxruntime<=1.15.1->inference)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in c:\users\covid\anaconda3\lib\site-packages (from onnxruntime<=1.15.1->inference) (23.5.26)
# Requirement already satisfied: protobuf in c:\users\covid\anaconda3\lib\site-packages (from onnxruntime<=1.15.1->inference) (4.21.2)
# Requirement already satisfied: sympy in c:\users\covid\anaconda3\lib\site-packages (from onnxruntime<=1.15.1->inference) (1.11.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\covid\anaconda3\lib\site-packages (from openai>=1.12.0->inference) (3.5.0)
# Collecting distro<2,>=1.7.0 (from openai>=1.12.0->inference)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai>=1.12.0->inference)
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: sniffio in c:\users\covid\anaconda3\lib\site-packages (from openai>=1.12.0->inference) (1.2.0)
# Requirement already satisfied: prometheus-client<1.0.0,>=0.8.0 in c:\users\covid\anaconda3\lib\site-packages (from prometheus-fastapi-instrumentator<=6.0.0->inference) (0.14.1)
# Collecting annotated-types>=0.4.0 (from pydantic~=2.6->inference)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.20.1 (from pydantic~=2.6->inference)
#   Downloading pydantic_core-2.20.1-cp310-none-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: pyparsing>=3 in c:\users\covid\anaconda3\lib\site-packages (from pydot>=2.0.0->inference) (3.0.9)
# Requirement already satisfied: pytest>=7.0.0 in c:\users\covid\anaconda3\lib\site-packages (from pytest-asyncio<=0.21.1->inference) (7.1.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\covid\anaconda3\lib\site-packages (from requests>=2.26.0->inference) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\covid\anaconda3\lib\site-packages (from requests>=2.26.0->inference) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\covid\anaconda3\lib\site-packages (from requests>=2.26.0->inference) (2023.7.22)
# Collecting markdown-it-py>=2.2.0 (from rich<=13.5.2->inference)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting pygments<3.0.0,>=2.13.0 (from rich<=13.5.2->inference)
#   Downloading pygments-2.18.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\covid\anaconda3\lib\site-packages (from scikit-image>=0.19.0->inference) (1.10.0)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\covid\anaconda3\lib\site-packages (from scikit-image>=0.19.0->inference) (2.26.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\covid\anaconda3\lib\site-packages (from scikit-image>=0.19.0->inference) (2021.7.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\covid\anaconda3\lib\site-packages (from scikit-image>=0.19.0->inference) (1.4.1)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in c:\users\covid\anaconda3\lib\site-packages (from supervision<1.0.0,>=0.20.0->inference) (0.7.1)
# Requirement already satisfied: matplotlib>=3.6.0 in c:\users\covid\anaconda3\lib\site-packages (from supervision<1.0.0,>=0.20.0->inference) (3.7.0)
# Requirement already satisfied: opencv-python-headless>=4.5.5.64 in c:\users\covid\anaconda3\lib\site-packages (from supervision<1.0.0,>=0.20.0->inference) (4.10.0.84)
# Collecting docutils<0.17,>=0.10 (from awscli>=1.27.10->skypilot[aws,gcp]==0.5.0->inference)
#   Downloading docutils-0.16-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting rsa<4.8,>=3.1.2 (from awscli>=1.27.10->skypilot[aws,gcp]==0.5.0->inference)
#   Downloading rsa-4.7.2-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\covid\anaconda3\lib\site-packages (from botocore>=1.29.10->skypilot[aws,gcp]==0.5.0->inference) (2.8.2)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in c:\users\covid\anaconda3\lib\site-packages (from google-api-python-client>=2.69.0->skypilot[aws,gcp]==0.5.0->inference) (0.22.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in c:\users\covid\anaconda3\lib\site-packages (from google-api-python-client>=2.69.0->skypilot[aws,gcp]==0.5.0->inference) (2.19.1)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in c:\users\covid\anaconda3\lib\site-packages (from google-api-python-client>=2.69.0->skypilot[aws,gcp]==0.5.0->inference) (0.1.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in c:\users\covid\anaconda3\lib\site-packages (from google-api-python-client>=2.69.0->skypilot[aws,gcp]==0.5.0->inference) (2.11.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\covid\anaconda3\lib\site-packages (from google-api-python-client>=2.69.0->skypilot[aws,gcp]==0.5.0->inference) (4.1.1)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai>=1.12.0->inference)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.12.0->inference)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\covid\anaconda3\lib\site-packages (from jinja2>=3.0->skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference) (2.1.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<=13.5.2->inference)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\covid\anaconda3\lib\site-packages (from matplotlib>=3.6.0->supervision<1.0.0,>=0.20.0->inference) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\covid\anaconda3\lib\site-packages (from matplotlib>=3.6.0->supervision<1.0.0,>=0.20.0->inference) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\covid\anaconda3\lib\site-packages (from matplotlib>=3.6.0->supervision<1.0.0,>=0.20.0->inference) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\covid\anaconda3\lib\site-packages (from matplotlib>=3.6.0->supervision<1.0.0,>=0.20.0->inference) (1.4.4)
# Requirement already satisfied: wcwidth in c:\users\covid\anaconda3\lib\site-packages (from PrettyTable>=2.0.0->skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference) (0.2.5)
# Requirement already satisfied: iniconfig in c:\users\covid\anaconda3\lib\site-packages (from pytest>=7.0.0->pytest-asyncio<=0.21.1->inference) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\covid\anaconda3\lib\site-packages (from pytest>=7.0.0->pytest-asyncio<=0.21.1->inference) (1.0.0)
# Requirement already satisfied: py>=1.8.2 in c:\users\covid\anaconda3\lib\site-packages (from pytest>=7.0.0->pytest-asyncio<=0.21.1->inference) (1.11.0)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\covid\anaconda3\lib\site-packages (from pytest>=7.0.0->pytest-asyncio<=0.21.1->inference) (2.0.1)
# Requirement already satisfied: atomicwrites>=1.0 in c:\users\covid\anaconda3\lib\site-packages (from pytest>=7.0.0->pytest-asyncio<=0.21.1->inference) (1.4.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\covid\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json>=0.6.0->inference) (0.4.3)
# Collecting tzdata (from tzlocal!=3.*,>=2.0->APScheduler<=3.10.1->inference)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime<=1.15.1->inference)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: cffi>=1.12 in c:\users\covid\anaconda3\lib\site-packages (from cryptography->skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference) (1.15.1)
# Collecting google-auth<3.0.0dev,>=1.19.0 (from google-api-python-client>=2.69.0->skypilot[aws,gcp]==0.5.0->inference)
#   Downloading google_auth-2.31.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 (from google-api-python-client>=2.69.0->skypilot[aws,gcp]==0.5.0->inference)
#   Downloading google_api_core-2.19.1-py3-none-any.whl.metadata (2.7 kB)
# Collecting google-cloud-core<3.0dev,>=2.3.0 (from google-cloud-storage->skypilot[aws,gcp]==0.5.0->inference)
#   Downloading google_cloud_core-2.4.1-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting google-resumable-media>=2.6.0 (from google-cloud-storage->skypilot[aws,gcp]==0.5.0->inference)
#   Downloading google_resumable_media-2.7.1-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting google-crc32c<2.0dev,>=1.0 (from google-cloud-storage->skypilot[aws,gcp]==0.5.0->inference)
#   Downloading google_crc32c-1.5.0-cp310-cp310-win_amd64.whl.metadata (2.3 kB)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\covid\anaconda3\lib\site-packages (from jsonschema->skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference) (0.18.0)
# Collecting time-machine>=2.6.0 (from pendulum->skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference)
#   Downloading time_machine-2.14.2-cp310-cp310-win_amd64.whl.metadata (21 kB)
# Requirement already satisfied: mpmath>=0.19 in c:\users\covid\anaconda3\lib\site-packages (from sympy->onnxruntime<=1.15.1->inference) (1.2.1)
# Requirement already satisfied: pycparser in c:\users\covid\anaconda3\lib\site-packages (from cffi>=1.12->cryptography->skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference) (2.21)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\covid\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=2.69.0->skypilot[aws,gcp]==0.5.0->inference) (1.59.0)
# Collecting protobuf (from onnxruntime<=1.15.1->inference)
#   Downloading protobuf-5.27.2-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=2.69.0->skypilot[aws,gcp]==0.5.0->inference)
#   Downloading proto_plus-1.24.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\covid\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=2.69.0->skypilot[aws,gcp]==0.5.0->inference) (0.2.8)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime<=1.15.1->inference)
#   Downloading pyreadline3-3.4.1-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\covid\anaconda3\lib\site-packages (from rsa<4.8,>=3.1.2->awscli>=1.27.10->skypilot[aws,gcp]==0.5.0->inference) (0.4.8)
# Collecting protobuf (from onnxruntime<=1.15.1->inference)
#   Downloading protobuf-4.25.3-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Downloading inference-0.13.0-py3-none-any.whl (471 kB)
#    ---------------------------------------- 0.0/471.7 kB ? eta -:--:--
#    --------------------------------------- 471.7/471.7 kB 14.4 MB/s eta 0:00:00
# Downloading docker-6.1.3-py3-none-any.whl (148 kB)
#    ---------------------------------------- 0.0/148.1 kB ? eta -:--:--
#    ---------------------------------------- 148.1/148.1 kB ? eta 0:00:00
# Downloading skypilot-0.5.0-py3-none-any.whl (905 kB)
#    ---------------------------------------- 0.0/906.0 kB ? eta -:--:--
#    -------------------------- ------------ 614.4/906.0 kB 37.8 MB/s eta 0:00:01
#    --------------------------------------- 906.0/906.0 kB 19.1 MB/s eta 0:00:00
# Downloading typer-0.9.0-py3-none-any.whl (45 kB)
#    ---------------------------------------- 0.0/45.9 kB ? eta -:--:--
#    ---------------------------------------- 45.9/45.9 kB ? eta 0:00:00
# Downloading APScheduler-3.10.1-py3-none-any.whl (59 kB)
#    ---------------------------------------- 0.0/59.2 kB ? eta -:--:--
#    ---------------------------------------- 59.2/59.2 kB 3.3 MB/s eta 0:00:00
# Downloading boto3-1.34.123-py3-none-any.whl (139 kB)
#    ---------------------------------------- 0.0/139.3 kB ? eta -:--:--
#    ---------------------------------------- 139.3/139.3 kB 8.1 MB/s eta 0:00:00
# Downloading Cython-3.0.0-cp310-cp310-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    --------------------------- ------------ 1.9/2.8 MB 58.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 34.8 MB/s eta 0:00:00
# Downloading fastapi-0.110.3-py3-none-any.whl (91 kB)
#    ---------------------------------------- 0.0/91.8 kB ? eta -:--:--
#    ---------------------------------------- 91.8/91.8 kB ? eta 0:00:00
# Downloading networkx-3.3-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 54.6 MB/s eta 0:00:00
# Downloading onnxruntime-1.15.1-cp310-cp310-win_amd64.whl (6.7 MB)
#    ---------------------------------------- 0.0/6.7 MB ? eta -:--:--
#    ------------------------------- -------- 5.2/6.7 MB 83.1 MB/s eta 0:00:01
#    ---------------------------------------- 6.7/6.7 MB 85.2 MB/s eta 0:00:00
# Downloading openai-1.35.10-py3-none-any.whl (328 kB)
#    ---------------------------------------- 0.0/328.3 kB ? eta -:--:--
#    ---------------------------------------- 328.3/328.3 kB ? eta 0:00:00
# Downloading opencv_python-4.8.0.76-cp37-abi3-win_amd64.whl (38.1 MB)
#    ---------------------------------------- 0.0/38.1 MB ? eta -:--:--
#    ----- ---------------------------------- 5.0/38.1 MB 107.0 MB/s eta 0:00:01
#    ---------- ----------------------------- 10.2/38.1 MB 108.4 MB/s eta 0:00:01
#    --------------- ------------------------ 14.9/38.1 MB 93.9 MB/s eta 0:00:01
#    -------------------- ------------------- 19.7/38.1 MB 110.0 MB/s eta 0:00:01
#    -------------------------- ------------- 24.8/38.1 MB 108.8 MB/s eta 0:00:01
#    ------------------------------- -------- 30.1/38.1 MB 108.8 MB/s eta 0:00:01
#    ------------------------------------- -- 35.5/38.1 MB 108.8 MB/s eta 0:00:01
#    ---------------------------------------  38.1/38.1 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------------- 38.1/38.1 MB 73.0 MB/s eta 0:00:00
# Downloading piexif-1.1.3-py2.py3-none-any.whl (20 kB)
# Downloading prometheus_fastapi_instrumentator-6.0.0-py3-none-any.whl (18 kB)
# Downloading pybase64-1.3.2-cp310-cp310-win_amd64.whl (34 kB)
# Downloading pydantic-2.8.2-py3-none-any.whl (423 kB)
#    ---------------------------------------- 0.0/423.9 kB ? eta -:--:--
#    ---------------------------------------- 423.9/423.9 kB ? eta 0:00:00
# Downloading pydantic_core-2.20.1-cp310-none-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 1.9/1.9 MB 61.0 MB/s eta 0:00:00
# Downloading pydot-2.0.0-py3-none-any.whl (22 kB)
# Downloading pytest_asyncio-0.21.1-py3-none-any.whl (13 kB)
# Downloading redis-5.0.7-py3-none-any.whl (252 kB)
#    ---------------------------------------- 0.0/252.1 kB ? eta -:--:--
#    ---------------------------------------- 252.1/252.1 kB ? eta 0:00:00
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading rich-13.5.2-py3-none-any.whl (239 kB)
#    ---------------------------------------- 0.0/239.7 kB ? eta -:--:--
#    --------------------------------------- 239.7/239.7 kB 14.3 MB/s eta 0:00:00
# Downloading shapely-2.0.4-cp310-cp310-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 95.3 MB/s eta 0:00:00
# Downloading structlog-24.2.0-py3-none-any.whl (65 kB)
#    ---------------------------------------- 0.0/65.8 kB ? eta -:--:--
#    ---------------------------------------- 65.8/65.8 kB ? eta 0:00:00
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading zxing_cpp-2.2.0-cp310-cp310-win_amd64.whl (692 kB)
#    ---------------------------------------- 0.0/692.0 kB ? eta -:--:--
#    --------------------------------------- 692.0/692.0 kB 22.0 MB/s eta 0:00:00
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading awscli-1.33.21-py3-none-any.whl (4.5 MB)
#    ---------------------------------------- 0.0/4.5 MB ? eta -:--:--
#    ---------------------------------- ----- 3.9/4.5 MB 241.3 MB/s eta 0:00:01
#    ---------------------------------------- 4.5/4.5 MB 95.1 MB/s eta 0:00:00
# Downloading botocore-1.34.139-py3-none-any.whl (12.4 MB)
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ------------- -------------------------- 4.1/12.4 MB 86.5 MB/s eta 0:00:01
#    ------------------------------ --------- 9.3/12.4 MB 99.1 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.4 MB 108.8 MB/s eta 0:00:01
#    ---------------------------------------- 12.4/12.4 MB 81.8 MB/s eta 0:00:00
# Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#    ---------------------------------------- 0.0/75.6 kB ? eta -:--:--
#    ---------------------------------------- 75.6/75.6 kB 4.4 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ---------------------------------------- 0.0/77.9 kB ? eta -:--:--
#    ---------------------------------------- 77.9/77.9 kB 4.2 MB/s eta 0:00:00
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ---------------------------------------- 0.0/87.5 kB ? eta -:--:--
#    ---------------------------------------- 87.5/87.5 kB ? eta 0:00:00
# Downloading prettytable-3.10.0-py3-none-any.whl (28 kB)
# Downloading pygments-2.18.0-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 74.7 MB/s eta 0:00:00
# Downloading s3transfer-0.10.2-py3-none-any.whl (82 kB)
#    ---------------------------------------- 0.0/82.7 kB ? eta -:--:--
#    ---------------------------------------- 82.7/82.7 kB ? eta 0:00:00
# Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#    ---------------------------------------- 0.0/71.9 kB ? eta -:--:--
#    ---------------------------------------- 71.9/71.9 kB ? eta 0:00:00
# Downloading tzlocal-5.2-py3-none-any.whl (17 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ---------------------------------------- 0.0/46.0 kB ? eta -:--:--
#    ---------------------------------------- 46.0/46.0 kB ? eta 0:00:00
# Downloading google_cloud_storage-2.17.0-py2.py3-none-any.whl (126 kB)
#    ---------------------------------------- 0.0/126.5 kB ? eta -:--:--
#    ---------------------------------------- 126.5/126.5 kB ? eta 0:00:00
# Downloading pendulum-3.0.0-cp310-none-win_amd64.whl (293 kB)
#    ---------------------------------------- 0.0/293.5 kB ? eta -:--:--
#    --------------------------------------- 293.5/293.5 kB 17.7 MB/s eta 0:00:00
# Downloading PuLP-2.8.0-py3-none-any.whl (17.7 MB)
#    ---------------------------------------- 0.0/17.7 MB ? eta -:--:--
#    --------- ------------------------------ 4.2/17.7 MB 90.0 MB/s eta 0:00:01
#    -------------------- ------------------- 9.2/17.7 MB 117.5 MB/s eta 0:00:01
#    ------------------------------- -------- 14.1/17.7 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------------  17.7/17.7 MB 108.8 MB/s eta 0:00:01
#    ---------------------------------------- 17.7/17.7 MB 93.8 MB/s eta 0:00:00
# Downloading docutils-0.16-py2.py3-none-any.whl (548 kB)
#    ---------------------------------------- 0.0/548.2 kB ? eta -:--:--
#    ---------------------------------------- 548.2/548.2 kB ? eta 0:00:00
# Downloading google_api_core-2.19.1-py3-none-any.whl (139 kB)
#    ---------------------------------------- 0.0/139.4 kB ? eta -:--:--
#    ---------------------------------------- 139.4/139.4 kB 8.6 MB/s eta 0:00:00
# Downloading google_auth-2.31.0-py2.py3-none-any.whl (194 kB)
#    ---------------------------------------- 0.0/194.6 kB ? eta -:--:--
#    ---------------------------------------- 194.6/194.6 kB ? eta 0:00:00
# Downloading google_cloud_core-2.4.1-py2.py3-none-any.whl (29 kB)
# Downloading google_crc32c-1.5.0-cp310-cp310-win_amd64.whl (27 kB)
# Downloading google_resumable_media-2.7.1-py2.py3-none-any.whl (81 kB)
#    ---------------------------------------- 0.0/81.2 kB ? eta -:--:--
#    ---------------------------------------- 81.2/81.2 kB ? eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#    ---------------------------------------- 86.8/86.8 kB ? eta 0:00:00
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Downloading time_machine-2.14.2-cp310-cp310-win_amd64.whl (20 kB)
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ---------------------------------------- 0.0/345.4 kB ? eta -:--:--
#    --------------------------------------- 345.4/345.4 kB 20.9 MB/s eta 0:00:00
# Downloading protobuf-4.25.3-cp310-abi3-win_amd64.whl (413 kB)
#    ---------------------------------------- 0.0/413.4 kB ? eta -:--:--
#    --------------------------------------- 413.4/413.4 kB 25.2 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ---------------------------------------- 0.0/58.3 kB ? eta -:--:--
#    ---------------------------------------- 58.3/58.3 kB ? eta 0:00:00
# Downloading proto_plus-1.24.0-py3-none-any.whl (50 kB)
#    ---------------------------------------- 0.0/50.1 kB ? eta -:--:--
#    ---------------------------------------- 50.1/50.1 kB ? eta 0:00:00
# Downloading pyreadline3-3.4.1-py3-none-any.whl (95 kB)
#    ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#    ---------------------------------------- 95.2/95.2 kB 5.3 MB/s eta 0:00:00
# Building wheels for collected packages: GPUtil
#   Building wheel for GPUtil (setup.py): started
#   Building wheel for GPUtil (setup.py): finished with status 'done'
#   Created wheel for GPUtil: filename=GPUtil-1.4.0-py3-none-any.whl size=7400 sha256=fa2d0ec5d683199485debbc802b8644d9174f71e35d89ba0ce68fedc5938687e
#   Stored in directory: c:\users\covid\appdata\local\pip\cache\wheels\a9\8a\bd\81082387151853ab8b6b3ef33426e98f5cbfebc3c397a9d4d0
# Successfully built GPUtil
# Installing collected packages: pyreadline3, GPUtil, zxing-cpp, tzdata, typing-extensions, structlog, shapely, rsa, redis, pygments, pydot, pybase64, pulp, protobuf, PrettyTable, piexif, opencv-python, networkx, mdurl, humanfriendly, h11, google-crc32c, docutils, distro, cython, colorama, annotated-types, tzlocal, time-machine, starlette, requests-toolbelt, pydantic-core, proto-plus, markdown-it-py, httpcore, google-resumable-media, google-auth, docker, coloredlogs, botocore, typer, s3transfer, rich, pytest-asyncio, pydantic, pendulum, onnxruntime, httpx, google-api-core, APScheduler, skypilot, openai, google-cloud-core, fastapi, boto3, awscli, prometheus-fastapi-instrumentator, google-cloud-storage, inference
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.4.0
#     Uninstalling typing_extensions-4.4.0:
#       Successfully uninstalled typing_extensions-4.4.0
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.9
#     Uninstalling rsa-4.9:
#       Successfully uninstalled rsa-4.9
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.11.2
#     Uninstalling Pygments-2.11.2:
#       Successfully uninstalled Pygments-2.11.2
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.21.2
#     Uninstalling protobuf-4.21.2:
#       Successfully uninstalled protobuf-4.21.2
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.10.0.84
#     Uninstalling opencv-python-4.10.0.84:
#       Successfully uninstalled opencv-python-4.10.0.84
#   Attempting uninstall: networkx
#     Found existing installation: networkx 2.8.4
#     Uninstalling networkx-2.8.4:
#       Successfully uninstalled networkx-2.8.4
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.18.1
#     Uninstalling docutils-0.18.1:
#       Successfully uninstalled docutils-0.18.1
#   Attempting uninstall: colorama
#     Found existing installation: colorama 0.4.6
#     Uninstalling colorama-0.4.6:
#       Successfully uninstalled colorama-0.4.6
#   Attempting uninstall: requests-toolbelt
#     Found existing installation: requests-toolbelt 0.9.1
#     Uninstalling requests-toolbelt-0.9.1:
#       Successfully uninstalled requests-toolbelt-0.9.1
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.19.1
#     Uninstalling google-auth-2.19.1:
#       Successfully uninstalled google-auth-2.19.1
#   Attempting uninstall: google-api-core
#     Found existing installation: google-api-core 2.11.0
#     Uninstalling google-api-core-2.11.0:
#       Successfully uninstalled google-api-core-2.11.0
# Successfully installed APScheduler-3.10.1 GPUtil-1.4.0 PrettyTable-3.10.0 annotated-types-0.7.0 awscli-1.33.21 boto3-1.34.123 botocore-1.34.139 colorama-0.4.4 coloredlogs-15.0.1 cython-3.0.0 distro-1.9.0 docker-6.1.3 docutils-0.16 fastapi-0.110.3 google-api-core-2.19.1 google-auth-2.31.0 google-cloud-core-2.4.1 google-cloud-storage-2.17.0 google-crc32c-1.5.0 google-resumable-media-2.7.1 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 humanfriendly-10.0 inference-0.13.0 markdown-it-py-3.0.0 mdurl-0.1.2 networkx-3.3 onnxruntime-1.15.1 openai-1.35.10 opencv-python-4.8.0.76 pendulum-3.0.0 piexif-1.1.3 prometheus-fastapi-instrumentator-6.0.0 proto-plus-1.24.0 protobuf-4.25.3 pulp-2.8.0 pybase64-1.3.2 pydantic-2.8.2 pydantic-core-2.20.1 pydot-2.0.0 pygments-2.18.0 pyreadline3-3.4.1 pytest-asyncio-0.21.1 redis-5.0.7 requests-toolbelt-1.0.0 rich-13.5.2 rsa-4.7.2 s3transfer-0.10.2 shapely-2.0.4 skypilot-0.5.0 starlette-0.37.2 structlog-24.2.0 time-machine-2.14.2 typer-0.9.0 typing-extensions-4.12.2 tzdata-2024.1 tzlocal-5.2 zxing-cpp-2.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pylint 2.16.2 requires colorama>=0.4.5; sys_platform == "win32", but you have colorama 0.4.4 which is incompatible.
#
# [notice] A new release of pip is available: 23.3.1 -> 24.1.1
# [notice] To update, run: C:\Users\covid\anaconda3\python.exe -m pip install --upgrade pip

# %%
# !pip install inference_sdk
# Out:
# Requirement already satisfied: inference_sdk in c:\users\covid\anaconda3\lib\site-packages (0.13.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\covid\anaconda3\lib\site-packages (from inference_sdk) (2.28.1)
# Requirement already satisfied: dataclasses-json>=0.6.0 in c:\users\covid\anaconda3\lib\site-packages (from inference_sdk) (0.6.7)
# Requirement already satisfied: opencv-python>=4.8.0.0 in c:\users\covid\anaconda3\lib\site-packages (from inference_sdk) (4.8.0.76)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\covid\anaconda3\lib\site-packages (from inference_sdk) (9.4.0)
# Requirement already satisfied: supervision<1.0.0,>=0.20.0 in c:\users\covid\anaconda3\lib\site-packages (from inference_sdk) (0.21.0)
# Requirement already satisfied: numpy<=1.26.4 in c:\users\covid\anaconda3\lib\site-packages (from inference_sdk) (1.23.5)
# Requirement already satisfied: aiohttp>=3.9.0 in c:\users\covid\anaconda3\lib\site-packages (from inference_sdk) (3.9.5)
# Requirement already satisfied: backoff>=2.2.0 in c:\users\covid\anaconda3\lib\site-packages (from inference_sdk) (2.2.1)
# Requirement already satisfied: aioresponses>=0.7.6 in c:\users\covid\anaconda3\lib\site-packages (from inference_sdk) (0.7.6)
# Requirement already satisfied: py-cpuinfo>=9.0.0 in c:\users\covid\anaconda3\lib\site-packages (from inference_sdk) (9.0.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\covid\anaconda3\lib\site-packages (from aiohttp>=3.9.0->inference_sdk) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\covid\anaconda3\lib\site-packages (from aiohttp>=3.9.0->inference_sdk) (22.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\covid\anaconda3\lib\site-packages (from aiohttp>=3.9.0->inference_sdk) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\covid\anaconda3\lib\site-packages (from aiohttp>=3.9.0->inference_sdk) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\covid\anaconda3\lib\site-packages (from aiohttp>=3.9.0->inference_sdk) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\covid\anaconda3\lib\site-packages (from aiohttp>=3.9.0->inference_sdk) (4.0.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\covid\anaconda3\lib\site-packages (from dataclasses-json>=0.6.0->inference_sdk) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\covid\anaconda3\lib\site-packages (from dataclasses-json>=0.6.0->inference_sdk) (0.9.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\covid\anaconda3\lib\site-packages (from requests>=2.0.0->inference_sdk) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\covid\anaconda3\lib\site-packages (from requests>=2.0.0->inference_sdk) (3.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\covid\anaconda3\lib\site-packages (from requests>=2.0.0->inference_sdk) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\covid\anaconda3\lib\site-packages (from requests>=2.0.0->inference_sdk) (2023.7.22)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in c:\users\covid\anaconda3\lib\site-packages (from supervision<1.0.0,>=0.20.0->inference_sdk) (0.7.1)
# Requirement already satisfied: matplotlib>=3.6.0 in c:\users\covid\anaconda3\lib\site-packages (from supervision<1.0.0,>=0.20.0->inference_sdk) (3.7.0)
# Requirement already satisfied: opencv-python-headless>=4.5.5.64 in c:\users\covid\anaconda3\lib\site-packages (from supervision<1.0.0,>=0.20.0->inference_sdk) (4.10.0.84)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\covid\anaconda3\lib\site-packages (from supervision<1.0.0,>=0.20.0->inference_sdk) (6.0)
# Requirement already satisfied: scipy<2.0.0,>=1.10.0 in c:\users\covid\anaconda3\lib\site-packages (from supervision<1.0.0,>=0.20.0->inference_sdk) (1.10.0)
# Requirement already satisfied: packaging>=17.0 in c:\users\covid\anaconda3\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json>=0.6.0->inference_sdk) (22.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\covid\anaconda3\lib\site-packages (from matplotlib>=3.6.0->supervision<1.0.0,>=0.20.0->inference_sdk) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\covid\anaconda3\lib\site-packages (from matplotlib>=3.6.0->supervision<1.0.0,>=0.20.0->inference_sdk) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\covid\anaconda3\lib\site-packages (from matplotlib>=3.6.0->supervision<1.0.0,>=0.20.0->inference_sdk) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\covid\anaconda3\lib\site-packages (from matplotlib>=3.6.0->supervision<1.0.0,>=0.20.0->inference_sdk) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\covid\anaconda3\lib\site-packages (from matplotlib>=3.6.0->supervision<1.0.0,>=0.20.0->inference_sdk) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\covid\anaconda3\lib\site-packages (from matplotlib>=3.6.0->supervision<1.0.0,>=0.20.0->inference_sdk) (2.8.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\covid\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json>=0.6.0->inference_sdk) (0.4.3)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\covid\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json>=0.6.0->inference_sdk) (4.12.2)
# Requirement already satisfied: six in c:\users\covid\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=3.6.0->supervision<1.0.0,>=0.20.0->inference_sdk) (1.16.0)
# [notice] A new release of pip is available: 23.3.1 -> 24.1.1
# [notice] To update, run: C:\Users\covid\anaconda3\python.exe -m pip install --upgrade pip

# %%
# !pip install InferenceHTTPClient
# Out:
# ERROR: Could not find a version that satisfies the requirement InferenceHTTPClient (from versions: none)
# ERROR: No matching distribution found for InferenceHTTPClient
#
# [notice] A new release of pip is available: 23.3.1 -> 24.1.1
# [notice] To update, run: C:\Users\covid\anaconda3\python.exe -m pip install --upgrade pip

# %%
pip install inference-gpu
# Out:
# Collecting inference-gpu
#   Downloading inference_gpu-0.13.0-py3-none-any.whl.metadata (14 kB)
# Collecting APScheduler<=3.10.1 (from inference-gpu)
#   Using cached APScheduler-3.10.1-py3-none-any.whl.metadata (5.7 kB)
# Collecting cython<=3.0.0 (from inference-gpu)
#   Using cached Cython-3.0.0-cp310-cp310-win_amd64.whl.metadata (3.2 kB)
# Requirement already satisfied: python-dotenv<=2.0.0 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from inference-gpu) (1.0.1)
# Collecting fastapi<0.111,>=0.100 (from inference-gpu)
#   Using cached fastapi-0.110.3-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: numpy<=1.26.4 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from inference-gpu) (1.26.1)
# Collecting opencv-python<=4.8.0.76 (from inference-gpu)
#   Using cached opencv_python-4.8.0.76-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting piexif<=1.1.3 (from inference-gpu)
#   Using cached piexif-1.1.3-py2.py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: pillow<11.0 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from inference-gpu) (10.1.0)
# Collecting prometheus-fastapi-instrumentator<=6.0.0 (from inference-gpu)
#   Using cached prometheus_fastapi_instrumentator-6.0.0-py3-none-any.whl.metadata (13 kB)
# Collecting redis<6.0.0 (from inference-gpu)
#   Using cached redis-5.0.7-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: requests>=2.26.0 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from inference-gpu) (2.31.0)
# Collecting rich<=13.5.2 (from inference-gpu)
#   Using cached rich-13.5.2-py3-none-any.whl.metadata (18 kB)
# Collecting supervision<1.0.0,>=0.20.0 (from inference-gpu)
#   Using cached supervision-0.21.0-py3-none-any.whl.metadata (13 kB)
# Collecting pybase64<2.0.0 (from inference-gpu)
#   Using cached pybase64-1.3.2-cp310-cp310-win_amd64.whl.metadata (8.2 kB)
# Collecting scikit-image>=0.19.0 (from inference-gpu)
#   Downloading scikit_image-0.24.0-cp310-cp310-win_amd64.whl.metadata (14 kB)
# Collecting requests-toolbelt>=1.0.0 (from inference-gpu)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: wheel>=0.38.1 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from inference-gpu) (0.41.2)
# Requirement already satisfied: setuptools<70.0.0,>=65.5.1 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from inference-gpu) (68.0.0)
# Collecting pytest-asyncio<=0.21.1 (from inference-gpu)
#   Using cached pytest_asyncio-0.21.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: networkx>=3.1 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from inference-gpu) (3.2.1)
# Collecting pydantic~=2.6 (from inference-gpu)
#   Using cached pydantic-2.8.2-py3-none-any.whl.metadata (125 kB)
# Collecting openai>=1.12.0 (from inference-gpu)
#   Using cached openai-1.35.10-py3-none-any.whl.metadata (21 kB)
# Collecting structlog>=24.1.0 (from inference-gpu)
#   Using cached structlog-24.2.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting zxing-cpp>=2.2.0 (from inference-gpu)
#   Using cached zxing_cpp-2.2.0-cp310-cp310-win_amd64.whl.metadata (1.9 kB)
# Collecting boto3<=1.34.123 (from inference-gpu)
#   Using cached boto3-1.34.123-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from inference-gpu) (4.8.0)
# Collecting pydot>=2.0.0 (from inference-gpu)
#   Using cached pydot-2.0.0-py3-none-any.whl.metadata (9.6 kB)
# Collecting shapely<2.1.0,>=2.0.0 (from inference-gpu)
#   Using cached shapely-2.0.4-cp310-cp310-win_amd64.whl.metadata (7.2 kB)
# Collecting onnxruntime-gpu<=1.15.1 (from inference-gpu)
#   Downloading onnxruntime_gpu-1.15.1-cp310-cp310-win_amd64.whl.metadata (4.1 kB)
# Collecting docker==6.1.3 (from inference-gpu)
#   Using cached docker-6.1.3-py3-none-any.whl.metadata (3.5 kB)
# Collecting typer==0.9.0 (from inference-gpu)
#   Using cached typer-0.9.0-py3-none-any.whl.metadata (14 kB)
# Collecting skypilot==0.5.0 (from skypilot[aws,gcp]==0.5.0->inference-gpu)
#   Using cached skypilot-0.5.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from inference-gpu) (6.0.1)
# Requirement already satisfied: tqdm>=4.0.0 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from inference-gpu) (4.66.1)
# Collecting GPUtil>=1.4.0 (from inference-gpu)
#   Using cached GPUtil-1.4.0-py3-none-any.whl
# Requirement already satisfied: py-cpuinfo>=9.0.0 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from inference-gpu) (9.0.0)
# Collecting aiohttp>=3.9.0 (from inference-gpu)
#   Using cached aiohttp-3.9.5-cp310-cp310-win_amd64.whl.metadata (7.7 kB)
# Collecting backoff>=2.2.0 (from inference-gpu)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting dataclasses-json>=0.6.0 (from inference-gpu)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting aioresponses>=0.7.6 (from inference-gpu)
#   Using cached aioresponses-0.7.6-py2.py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: packaging>=14.0 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from docker==6.1.3->inference-gpu) (23.2)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from docker==6.1.3->inference-gpu) (2.0.7)
# Collecting websocket-client>=0.32.0 (from docker==6.1.3->inference-gpu)
#   Downloading websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: pywin32>=304 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from docker==6.1.3->inference-gpu) (306)
# Requirement already satisfied: cachetools in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference-gpu) (5.3.2)
# Collecting click>=7.0 (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference-gpu)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: colorama in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference-gpu) (0.4.6)
# Collecting cryptography (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference-gpu)
#   Downloading cryptography-42.0.8-cp39-abi3-win_amd64.whl.metadata (5.4 kB)
# Requirement already satisfied: jinja2>=3.0 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference-gpu) (3.1.2)
# Collecting jsonschema (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference-gpu)
#   Downloading jsonschema-4.22.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference-gpu) (2.1.2)
# Collecting pendulum (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference-gpu)
#   Using cached pendulum-3.0.0-cp310-none-win_amd64.whl.metadata (7.0 kB)
# Collecting PrettyTable>=2.0.0 (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference-gpu)
#   Using cached prettytable-3.10.0-py3-none-any.whl.metadata (30 kB)
# Collecting tabulate (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference-gpu)
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: filelock>=3.6.0 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference-gpu) (3.13.0)
# Requirement already satisfied: psutil in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference-gpu) (5.9.6)
# Collecting pulp (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference-gpu)
#   Using cached PuLP-2.8.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting urllib3>=1.26.0 (from docker==6.1.3->inference-gpu)
#   Downloading urllib3-1.26.19-py2.py3-none-any.whl.metadata (49 kB)
#      ---------------------------------------- 0.0/49.3 kB ? eta -:--:--
#      ---------------------------------------- 49.3/49.3 kB 2.4 MB/s eta 0:00:00
# Collecting awscli>=1.27.10 (from skypilot[aws,gcp]==0.5.0->inference-gpu)
#   Using cached awscli-1.33.21-py3-none-any.whl.metadata (11 kB)
# Collecting botocore>=1.29.10 (from skypilot[aws,gcp]==0.5.0->inference-gpu)
#   Using cached botocore-1.34.139-py3-none-any.whl.metadata (5.7 kB)
# Collecting colorama (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference-gpu)
#   Using cached colorama-0.4.4-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: google-api-python-client>=2.69.0 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from skypilot[aws,gcp]==0.5.0->inference-gpu) (2.105.0)
# Collecting google-cloud-storage (from skypilot[aws,gcp]==0.5.0->inference-gpu)
#   Using cached google_cloud_storage-2.17.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp>=3.9.0->inference-gpu)
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting attrs>=17.3.0 (from aiohttp>=3.9.0->inference-gpu)
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp>=3.9.0->inference-gpu)
#   Using cached frozenlist-1.4.1-cp310-cp310-win_amd64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp>=3.9.0->inference-gpu)
#   Using cached multidict-6.0.5-cp310-cp310-win_amd64.whl.metadata (4.3 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp>=3.9.0->inference-gpu)
#   Using cached yarl-1.9.4-cp310-cp310-win_amd64.whl.metadata (32 kB)
# Collecting async-timeout<5.0,>=4.0 (from aiohttp>=3.9.0->inference-gpu)
#   Using cached async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: six>=1.4.0 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from APScheduler<=3.10.1->inference-gpu) (1.16.0)
# Requirement already satisfied: pytz in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from APScheduler<=3.10.1->inference-gpu) (2023.3.post1)
# Collecting tzlocal!=3.*,>=2.0 (from APScheduler<=3.10.1->inference-gpu)
#   Using cached tzlocal-5.2-py3-none-any.whl.metadata (7.8 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<=1.34.123->inference-gpu)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3<=1.34.123->inference-gpu)
#   Using cached s3transfer-0.10.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json>=0.6.0->inference-gpu)
#   Using cached marshmallow-3.21.3-py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json>=0.6.0->inference-gpu)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi<0.111,>=0.100->inference-gpu)
#   Using cached starlette-0.37.2-py3-none-any.whl.metadata (5.9 kB)
# Collecting coloredlogs (from onnxruntime-gpu<=1.15.1->inference-gpu)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from onnxruntime-gpu<=1.15.1->inference-gpu) (23.5.26)
# Requirement already satisfied: protobuf in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from onnxruntime-gpu<=1.15.1->inference-gpu) (3.19.6)
# Requirement already satisfied: sympy in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from onnxruntime-gpu<=1.15.1->inference-gpu) (1.12)
# Collecting anyio<5,>=3.5.0 (from openai>=1.12.0->inference-gpu)
#   Downloading anyio-4.4.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting distro<2,>=1.7.0 (from openai>=1.12.0->inference-gpu)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai>=1.12.0->inference-gpu)
#   Using cached httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting sniffio (from openai>=1.12.0->inference-gpu)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting prometheus-client<1.0.0,>=0.8.0 (from prometheus-fastapi-instrumentator<=6.0.0->inference-gpu)
#   Downloading prometheus_client-0.20.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting annotated-types>=0.4.0 (from pydantic~=2.6->inference-gpu)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.20.1 (from pydantic~=2.6->inference-gpu)
#   Using cached pydantic_core-2.20.1-cp310-none-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: pyparsing>=3 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from pydot>=2.0.0->inference-gpu) (3.1.1)
# Collecting pytest>=7.0.0 (from pytest-asyncio<=0.21.1->inference-gpu)
#   Downloading pytest-8.2.2-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from requests>=2.26.0->inference-gpu) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from requests>=2.26.0->inference-gpu) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from requests>=2.26.0->inference-gpu) (2023.7.22)
# Collecting markdown-it-py>=2.2.0 (from rich<=13.5.2->inference-gpu)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from rich<=13.5.2->inference-gpu) (2.16.1)
# Requirement already satisfied: scipy>=1.9 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from scikit-image>=0.19.0->inference-gpu) (1.11.3)
# Collecting imageio>=2.33 (from scikit-image>=0.19.0->inference-gpu)
#   Downloading imageio-2.34.2-py3-none-any.whl.metadata (4.9 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image>=0.19.0->inference-gpu)
#   Downloading tifffile-2024.7.2-py3-none-any.whl.metadata (30 kB)
# Collecting lazy-loader>=0.4 (from scikit-image>=0.19.0->inference-gpu)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting defusedxml<0.8.0,>=0.7.1 (from supervision<1.0.0,>=0.20.0->inference-gpu)
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: matplotlib>=3.6.0 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from supervision<1.0.0,>=0.20.0->inference-gpu) (3.8.0)
# Collecting opencv-python-headless>=4.5.5.64 (from supervision<1.0.0,>=0.20.0->inference-gpu)
#   Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from anyio<5,>=3.5.0->openai>=1.12.0->inference-gpu) (1.1.3)
# Collecting docutils<0.17,>=0.10 (from awscli>=1.27.10->skypilot[aws,gcp]==0.5.0->inference-gpu)
#   Using cached docutils-0.16-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting rsa<4.8,>=3.1.2 (from awscli>=1.27.10->skypilot[aws,gcp]==0.5.0->inference-gpu)
#   Using cached rsa-4.7.2-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from botocore>=1.29.10->skypilot[aws,gcp]==0.5.0->inference-gpu) (2.8.2)
# Requirement already satisfied: httplib2<1.dev0,>=0.15.0 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from google-api-python-client>=2.69.0->skypilot[aws,gcp]==0.5.0->inference-gpu) (0.22.0)
# Requirement already satisfied: google-auth<3.0.0.dev0,>=1.19.0 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from google-api-python-client>=2.69.0->skypilot[aws,gcp]==0.5.0->inference-gpu) (2.23.3)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from google-api-python-client>=2.69.0->skypilot[aws,gcp]==0.5.0->inference-gpu) (0.1.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from google-api-python-client>=2.69.0->skypilot[aws,gcp]==0.5.0->inference-gpu) (2.12.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from google-api-python-client>=2.69.0->skypilot[aws,gcp]==0.5.0->inference-gpu) (4.1.1)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai>=1.12.0->inference-gpu)
#   Using cached httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.12.0->inference-gpu)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from jinja2>=3.0->skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference-gpu) (2.1.3)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<=13.5.2->inference-gpu)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from matplotlib>=3.6.0->supervision<1.0.0,>=0.20.0->inference-gpu) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from matplotlib>=3.6.0->supervision<1.0.0,>=0.20.0->inference-gpu) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from matplotlib>=3.6.0->supervision<1.0.0,>=0.20.0->inference-gpu) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from matplotlib>=3.6.0->supervision<1.0.0,>=0.20.0->inference-gpu) (1.4.5)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from pandas>=1.3.0->skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference-gpu) (2023.3)
# Requirement already satisfied: wcwidth in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from PrettyTable>=2.0.0->skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference-gpu) (0.2.8)
# Collecting iniconfig (from pytest>=7.0.0->pytest-asyncio<=0.21.1->inference-gpu)
#   Downloading iniconfig-2.0.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pluggy<2.0,>=1.5 (from pytest>=7.0.0->pytest-asyncio<=0.21.1->inference-gpu)
#   Downloading pluggy-1.5.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting tomli>=1 (from pytest>=7.0.0->pytest-asyncio<=0.21.1->inference-gpu)
#   Downloading tomli-2.0.1-py3-none-any.whl.metadata (8.9 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json>=0.6.0->inference-gpu)
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime-gpu<=1.15.1->inference-gpu)
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting cffi>=1.12 (from cryptography->skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference-gpu)
#   Downloading cffi-1.16.0-cp310-cp310-win_amd64.whl.metadata (1.5 kB)
# Collecting google-auth<3.0.0.dev0,>=1.19.0 (from google-api-python-client>=2.69.0->skypilot[aws,gcp]==0.5.0->inference-gpu)
#   Using cached google_auth-2.31.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 (from google-api-python-client>=2.69.0->skypilot[aws,gcp]==0.5.0->inference-gpu)
#   Using cached google_api_core-2.19.1-py3-none-any.whl.metadata (2.7 kB)
# Collecting google-cloud-core<3.0dev,>=2.3.0 (from google-cloud-storage->skypilot[aws,gcp]==0.5.0->inference-gpu)
#   Using cached google_cloud_core-2.4.1-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting google-resumable-media>=2.6.0 (from google-cloud-storage->skypilot[aws,gcp]==0.5.0->inference-gpu)
#   Using cached google_resumable_media-2.7.1-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting google-crc32c<2.0dev,>=1.0 (from google-cloud-storage->skypilot[aws,gcp]==0.5.0->inference-gpu)
#   Using cached google_crc32c-1.5.0-cp310-cp310-win_amd64.whl.metadata (2.3 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema->skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference-gpu)
#   Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema->skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference-gpu)
#   Downloading referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema->skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference-gpu)
#   Downloading rpds_py-0.18.1-cp310-none-win_amd64.whl.metadata (4.2 kB)
# Collecting time-machine>=2.6.0 (from pendulum->skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference-gpu)
#   Using cached time_machine-2.14.2-cp310-cp310-win_amd64.whl.metadata (21 kB)
# Requirement already satisfied: mpmath>=0.19 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from sympy->onnxruntime-gpu<=1.15.1->inference-gpu) (1.3.0)
# Collecting pycparser (from cffi>=1.12->cryptography->skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference-gpu)
#   Downloading pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=2.69.0->skypilot[aws,gcp]==0.5.0->inference-gpu) (1.61.0)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=2.69.0->skypilot[aws,gcp]==0.5.0->inference-gpu)
#   Using cached proto_plus-1.24.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client>=2.69.0->skypilot[aws,gcp]==0.5.0->inference-gpu) (0.3.0)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime-gpu<=1.15.1->inference-gpu)
#   Using cached pyreadline3-3.4.1-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\covid\anaconda3\envs\localgpu\lib\site-packages (from rsa<4.8,>=3.1.2->awscli>=1.27.10->skypilot[aws,gcp]==0.5.0->inference-gpu) (0.5.0)
# Downloading inference_gpu-0.13.0-py3-none-any.whl (471 kB)
#    ---------------------------------------- 0.0/471.7 kB ? eta -:--:--
#    --------------------------------------- 471.7/471.7 kB 28.8 MB/s eta 0:00:00
# Using cached docker-6.1.3-py3-none-any.whl (148 kB)
# Using cached skypilot-0.5.0-py3-none-any.whl (905 kB)
# Using cached typer-0.9.0-py3-none-any.whl (45 kB)
# Using cached aiohttp-3.9.5-cp310-cp310-win_amd64.whl (370 kB)
# Using cached aioresponses-0.7.6-py2.py3-none-any.whl (11 kB)
# Using cached APScheduler-3.10.1-py3-none-any.whl (59 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached boto3-1.34.123-py3-none-any.whl (139 kB)
# Using cached Cython-3.0.0-cp310-cp310-win_amd64.whl (2.8 MB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached fastapi-0.110.3-py3-none-any.whl (91 kB)
# Downloading onnxruntime_gpu-1.15.1-cp310-cp310-win_amd64.whl (122.5 MB)
#    ---------------------------------------- 0.0/122.5 MB ? eta -:--:--
#    ---------------------------------------- 1.3/122.5 MB 27.2 MB/s eta 0:00:05
#    - -------------------------------------- 3.6/122.5 MB 37.8 MB/s eta 0:00:04
#    -- ------------------------------------- 8.0/122.5 MB 64.2 MB/s eta 0:00:02
#    ---- ---------------------------------- 13.0/122.5 MB 108.8 MB/s eta 0:00:02
#    ----- --------------------------------- 17.8/122.5 MB 108.8 MB/s eta 0:00:01
#    ------- ------------------------------- 22.8/122.5 MB 108.8 MB/s eta 0:00:01
#    -------- ------------------------------- 27.1/122.5 MB 93.9 MB/s eta 0:00:02
#    ---------- ----------------------------- 31.8/122.5 MB 93.9 MB/s eta 0:00:01
#    ----------- --------------------------- 36.6/122.5 MB 110.0 MB/s eta 0:00:01
#    ------------- ------------------------- 41.4/122.5 MB 110.0 MB/s eta 0:00:01
#    -------------- ------------------------- 45.3/122.5 MB 93.0 MB/s eta 0:00:01
#    --------------- ------------------------ 48.6/122.5 MB 93.9 MB/s eta 0:00:01
#    ----------------- ---------------------- 52.9/122.5 MB 81.8 MB/s eta 0:00:01
#    ------------------ --------------------- 57.2/122.5 MB 93.0 MB/s eta 0:00:01
#    -------------------- ------------------- 61.4/122.5 MB 93.0 MB/s eta 0:00:01
#    --------------------- ------------------ 65.6/122.5 MB 81.8 MB/s eta 0:00:01
#    ---------------------- ---------------- 70.5/122.5 MB 110.0 MB/s eta 0:00:01
#    ----------------------- --------------- 74.4/122.5 MB 110.0 MB/s eta 0:00:01
#    ------------------------- -------------- 77.2/122.5 MB 93.9 MB/s eta 0:00:01
#    -------------------------- ------------- 80.9/122.5 MB 72.6 MB/s eta 0:00:01
#    --------------------------- ------------ 84.6/122.5 MB 65.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 86.8/122.5 MB 65.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 89.1/122.5 MB 59.5 MB/s eta 0:00:01
#    ------------------------------ --------- 92.3/122.5 MB 54.7 MB/s eta 0:00:01
#    ------------------------------ --------- 94.5/122.5 MB 59.8 MB/s eta 0:00:01
#    ------------------------------- -------- 95.9/122.5 MB 46.7 MB/s eta 0:00:01
#    ------------------------------- -------- 97.1/122.5 MB 43.5 MB/s eta 0:00:01
#    -------------------------------- ------- 98.6/122.5 MB 43.7 MB/s eta 0:00:01
#    ------------------------------- ------- 100.2/122.5 MB 38.5 MB/s eta 0:00:01
#    -------------------------------- ------ 102.0/122.5 MB 36.4 MB/s eta 0:00:01
#    --------------------------------- ----- 103.8/122.5 MB 34.4 MB/s eta 0:00:01
#    --------------------------------- ----- 105.1/122.5 MB 32.8 MB/s eta 0:00:01
#    --------------------------------- ----- 106.3/122.5 MB 32.8 MB/s eta 0:00:01
#    ---------------------------------- ---- 107.9/122.5 MB 34.4 MB/s eta 0:00:01
#    ---------------------------------- ---- 109.3/122.5 MB 34.4 MB/s eta 0:00:01
#    ----------------------------------- --- 110.7/122.5 MB 31.2 MB/s eta 0:00:01
#    ----------------------------------- --- 112.1/122.5 MB 31.2 MB/s eta 0:00:01
#    ------------------------------------ -- 113.6/122.5 MB 29.8 MB/s eta 0:00:01
#    ------------------------------------- - 116.3/122.5 MB 34.4 MB/s eta 0:00:01
#    --------------------------------------  120.5/122.5 MB 50.4 MB/s eta 0:00:01
#    --------------------------------------  122.5/122.5 MB 65.6 MB/s eta 0:00:01
#    --------------------------------------  122.5/122.5 MB 65.6 MB/s eta 0:00:01
#    --------------------------------------  122.5/122.5 MB 65.6 MB/s eta 0:00:01
#    --------------------------------------- 122.5/122.5 MB 34.5 MB/s eta 0:00:00
# Using cached openai-1.35.10-py3-none-any.whl (328 kB)
# Using cached opencv_python-4.8.0.76-cp37-abi3-win_amd64.whl (38.1 MB)
# Using cached piexif-1.1.3-py2.py3-none-any.whl (20 kB)
# Using cached prometheus_fastapi_instrumentator-6.0.0-py3-none-any.whl (18 kB)
# Using cached pybase64-1.3.2-cp310-cp310-win_amd64.whl (34 kB)
# Using cached pydantic-2.8.2-py3-none-any.whl (423 kB)
# Using cached pydantic_core-2.20.1-cp310-none-win_amd64.whl (1.9 MB)
# Using cached pydot-2.0.0-py3-none-any.whl (22 kB)
# Using cached pytest_asyncio-0.21.1-py3-none-any.whl (13 kB)
# Using cached redis-5.0.7-py3-none-any.whl (252 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached rich-13.5.2-py3-none-any.whl (239 kB)
# Downloading scikit_image-0.24.0-cp310-cp310-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ------------- -------------------------- 4.3/12.9 MB 90.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 9.3/12.9 MB 99.0 MB/s eta 0:00:01
#    ---------------------------------------  12.9/12.9 MB 108.8 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 81.8 MB/s eta 0:00:00
# Using cached shapely-2.0.4-cp310-cp310-win_amd64.whl (1.4 MB)
# Using cached structlog-24.2.0-py3-none-any.whl (65 kB)
# Using cached supervision-0.21.0-py3-none-any.whl (123 kB)
# Using cached zxing_cpp-2.2.0-cp310-cp310-win_amd64.whl (692 kB)
# Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading anyio-4.4.0-py3-none-any.whl (86 kB)
#    ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#    ---------------------------------------- 86.8/86.8 kB ? eta 0:00:00
# Using cached async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Using cached awscli-1.33.21-py3-none-any.whl (4.5 MB)
# Using cached botocore-1.34.139-py3-none-any.whl (12.4 MB)
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
#    ---------------------------------------- 0.0/97.9 kB ? eta -:--:--
#    ---------------------------------------- 97.9/97.9 kB 5.5 MB/s eta 0:00:00
# Using cached colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached frozenlist-1.4.1-cp310-cp310-win_amd64.whl (50 kB)
# Using cached httpx-0.27.0-py3-none-any.whl (75 kB)
# Using cached httpcore-1.0.5-py3-none-any.whl (77 kB)
# Downloading imageio-2.34.2-py3-none-any.whl (313 kB)
#    ---------------------------------------- 0.0/313.5 kB ? eta -:--:--
#    ---------------------------------------- 313.5/313.5 kB ? eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached marshmallow-3.21.3-py3-none-any.whl (49 kB)
# Using cached multidict-6.0.5-cp310-cp310-win_amd64.whl (28 kB)
# Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
# Using cached prettytable-3.10.0-py3-none-any.whl (28 kB)
# Downloading prometheus_client-0.20.0-py3-none-any.whl (54 kB)
#    ---------------------------------------- 0.0/54.5 kB ? eta -:--:--
#    ---------------------------------------- 54.5/54.5 kB ? eta 0:00:00
# Downloading pytest-8.2.2-py3-none-any.whl (339 kB)
#    ---------------------------------------- 0.0/339.9 kB ? eta -:--:--
#    ---------------------------------------- 339.9/339.9 kB ? eta 0:00:00
# Using cached s3transfer-0.10.2-py3-none-any.whl (82 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached starlette-0.37.2-py3-none-any.whl (71 kB)
# Downloading tifffile-2024.7.2-py3-none-any.whl (225 kB)
#    ---------------------------------------- 0.0/225.9 kB ? eta -:--:--
#    ---------------------------------------- 225.9/225.9 kB ? eta 0:00:00
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached tzlocal-5.2-py3-none-any.whl (17 kB)
# Downloading urllib3-1.26.19-py2.py3-none-any.whl (143 kB)
#    ---------------------------------------- 0.0/143.9 kB ? eta -:--:--
#    ---------------------------------------- 143.9/143.9 kB ? eta 0:00:00
# Downloading websocket_client-1.8.0-py3-none-any.whl (58 kB)
#    ---------------------------------------- 0.0/58.8 kB ? eta -:--:--
#    ---------------------------------------- 58.8/58.8 kB ? eta 0:00:00
# Using cached yarl-1.9.4-cp310-cp310-win_amd64.whl (76 kB)
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Downloading cryptography-42.0.8-cp39-abi3-win_amd64.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ---------------------------------------- 2.9/2.9 MB 179.7 MB/s eta 0:00:00
# Using cached google_cloud_storage-2.17.0-py2.py3-none-any.whl (126 kB)
# Downloading jsonschema-4.22.0-py3-none-any.whl (88 kB)
#    ---------------------------------------- 0.0/88.3 kB ? eta -:--:--
#    ---------------------------------------- 88.3/88.3 kB ? eta 0:00:00
# Using cached pendulum-3.0.0-cp310-none-win_amd64.whl (293 kB)
# Using cached PuLP-2.8.0-py3-none-any.whl (17.7 MB)
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Downloading cffi-1.16.0-cp310-cp310-win_amd64.whl (181 kB)
#    ---------------------------------------- 0.0/181.6 kB ? eta -:--:--
#    ---------------------------------------- 181.6/181.6 kB ? eta 0:00:00
# Using cached docutils-0.16-py2.py3-none-any.whl (548 kB)
# Using cached google_api_core-2.19.1-py3-none-any.whl (139 kB)
# Using cached google_auth-2.31.0-py2.py3-none-any.whl (194 kB)
# Using cached google_cloud_core-2.4.1-py2.py3-none-any.whl (29 kB)
# Using cached google_crc32c-1.5.0-cp310-cp310-win_amd64.whl (27 kB)
# Using cached google_resumable_media-2.7.1-py2.py3-none-any.whl (81 kB)
# Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading pluggy-1.5.0-py3-none-any.whl (20 kB)
# Downloading referencing-0.35.1-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.18.1-cp310-none-win_amd64.whl (209 kB)
#    ---------------------------------------- 0.0/209.0 kB ? eta -:--:--
#    ---------------------------------------- 209.0/209.0 kB ? eta 0:00:00
# Using cached rsa-4.7.2-py3-none-any.whl (34 kB)
# Using cached time_machine-2.14.2-cp310-cp310-win_amd64.whl (20 kB)
# Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Downloading iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Using cached proto_plus-1.24.0-py3-none-any.whl (50 kB)
# Downloading pycparser-2.22-py3-none-any.whl (117 kB)
#    ---------------------------------------- 0.0/117.6 kB ? eta -:--:--
#    ---------------------------------------- 117.6/117.6 kB ? eta 0:00:00
# Using cached pyreadline3-3.4.1-py3-none-any.whl (95 kB)
# Installing collected packages: pyreadline3, GPUtil, zxing-cpp, websocket-client, urllib3, tzlocal, tomli, tifffile, tabulate, structlog, sniffio, shapely, rsa, rpds-py, pydot, pydantic-core, pycparser, pybase64, pulp, proto-plus, prometheus-client, PrettyTable, pluggy, piexif, opencv-python-headless, opencv-python, mypy-extensions, multidict, mdurl, marshmallow, lazy-loader, jmespath, iniconfig, imageio, humanfriendly, h11, google-crc32c, frozenlist, docutils, distro, defusedxml, cython, colorama, backoff, attrs, async-timeout, annotated-types, yarl, typing-inspect, time-machine, scikit-image, referencing, redis, pytest, pydantic, markdown-it-py, httpcore, google-resumable-media, google-auth, coloredlogs, click, cffi, botocore, APScheduler, anyio, aiosignal, typer, supervision, starlette, s3transfer, rich, requests-toolbelt, pytest-asyncio, pendulum, onnxruntime-gpu, jsonschema-specifications, httpx, google-api-core, docker, dataclasses-json, cryptography, aiohttp, openai, jsonschema, google-cloud-core, fastapi, boto3, awscli, aioresponses, skypilot, prometheus-fastapi-instrumentator, google-cloud-storage, inference-gpu
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.9
#     Uninstalling rsa-4.9:
#       Successfully uninstalled rsa-4.9
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script wsdump.exe is installed in 'C:\Users\covid\anaconda3\envs\localGPU\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts lsm2bin.exe, tiff2fsspec.exe, tiffcomment.exe and tifffile.exe are installed in 'C:\Users\covid\anaconda3\envs\localGPU\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tabulate.exe is installed in 'C:\Users\covid\anaconda3\envs\localGPU\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts pyrsa-decrypt.exe, pyrsa-encrypt.exe, pyrsa-keygen.exe, pyrsa-priv2pub.exe, pyrsa-sign.exe and pyrsa-verify.exe are installed in 'C:\Users\covid\anaconda3\envs\localGPU\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pybase64.exe is installed in 'C:\Users\covid\anaconda3\envs\localGPU\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pulptest.exe is installed in 'C:\Users\covid\anaconda3\envs\localGPU\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: Could not install packages due to an OSError: [WinError 5] アクセスが拒否されました。: 'C:\\Users\\covid\\anaconda3\\envs\\localGPU\\Lib\\site-packages\\cv2\\cv2.pyd'
# Consider using the `--user` option or check the permissions.

# %%
# !pip install inference
# Out:
# Requirement already satisfied: inference in c:\users\covid\anaconda3\lib\site-packages (0.13.0)
# Requirement already satisfied: APScheduler<=3.10.1 in c:\users\covid\anaconda3\lib\site-packages (from inference) (3.10.1)
# Requirement already satisfied: cython<=3.0.0 in c:\users\covid\anaconda3\lib\site-packages (from inference) (3.0.0)
# Requirement already satisfied: python-dotenv<=2.0.0 in c:\users\covid\anaconda3\lib\site-packages (from inference) (1.0.1)
# Requirement already satisfied: fastapi<0.111,>=0.100 in c:\users\covid\anaconda3\lib\site-packages (from inference) (0.110.3)
# Requirement already satisfied: numpy<=1.26.4 in c:\users\covid\anaconda3\lib\site-packages (from inference) (1.23.5)
# Requirement already satisfied: opencv-python<=4.8.0.76 in c:\users\covid\anaconda3\lib\site-packages (from inference) (4.8.0.76)
# Requirement already satisfied: piexif<=1.1.3 in c:\users\covid\anaconda3\lib\site-packages (from inference) (1.1.3)
# Requirement already satisfied: pillow<11.0 in c:\users\covid\anaconda3\lib\site-packages (from inference) (9.4.0)
# Requirement already satisfied: prometheus-fastapi-instrumentator<=6.0.0 in c:\users\covid\anaconda3\lib\site-packages (from inference) (6.0.0)
# Requirement already satisfied: redis<6.0.0 in c:\users\covid\anaconda3\lib\site-packages (from inference) (5.0.7)
# Requirement already satisfied: requests>=2.26.0 in c:\users\covid\anaconda3\lib\site-packages (from inference) (2.28.1)
# Requirement already satisfied: rich<=13.5.2 in c:\users\covid\anaconda3\lib\site-packages (from inference) (13.5.2)
# Requirement already satisfied: supervision<1.0.0,>=0.20.0 in c:\users\covid\anaconda3\lib\site-packages (from inference) (0.21.0)
# Requirement already satisfied: pybase64<2.0.0 in c:\users\covid\anaconda3\lib\site-packages (from inference) (1.3.2)
# Requirement already satisfied: scikit-image>=0.19.0 in c:\users\covid\anaconda3\lib\site-packages (from inference) (0.19.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\covid\anaconda3\lib\site-packages (from inference) (1.0.0)
# Requirement already satisfied: wheel>=0.38.1 in c:\users\covid\anaconda3\lib\site-packages (from inference) (0.38.4)
# Requirement already satisfied: setuptools<70.0.0,>=65.5.1 in c:\users\covid\anaconda3\lib\site-packages (from inference) (65.6.3)
# Requirement already satisfied: pytest-asyncio<=0.21.1 in c:\users\covid\anaconda3\lib\site-packages (from inference) (0.21.1)
# Requirement already satisfied: networkx>=3.1 in c:\users\covid\anaconda3\lib\site-packages (from inference) (3.3)
# Requirement already satisfied: pydantic~=2.6 in c:\users\covid\anaconda3\lib\site-packages (from inference) (2.8.2)
# Requirement already satisfied: openai>=1.12.0 in c:\users\covid\anaconda3\lib\site-packages (from inference) (1.35.10)
# Requirement already satisfied: structlog>=24.1.0 in c:\users\covid\anaconda3\lib\site-packages (from inference) (24.2.0)
# Requirement already satisfied: zxing-cpp>=2.2.0 in c:\users\covid\anaconda3\lib\site-packages (from inference) (2.2.0)
# Requirement already satisfied: boto3<=1.34.123 in c:\users\covid\anaconda3\lib\site-packages (from inference) (1.34.123)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\covid\anaconda3\lib\site-packages (from inference) (4.12.2)
# Requirement already satisfied: pydot>=2.0.0 in c:\users\covid\anaconda3\lib\site-packages (from inference) (2.0.0)
# Requirement already satisfied: shapely<2.1.0,>=2.0.0 in c:\users\covid\anaconda3\lib\site-packages (from inference) (2.0.4)
# Requirement already satisfied: onnxruntime<=1.15.1 in c:\users\covid\anaconda3\lib\site-packages (from inference) (1.15.1)
# Requirement already satisfied: GPUtil==1.4.0 in c:\users\covid\anaconda3\lib\site-packages (from inference) (1.4.0)
# Requirement already satisfied: docker==6.1.3 in c:\users\covid\anaconda3\lib\site-packages (from inference) (6.1.3)
# Requirement already satisfied: typer==0.9.0 in c:\users\covid\anaconda3\lib\site-packages (from inference) (0.9.0)
# Requirement already satisfied: skypilot==0.5.0 in c:\users\covid\anaconda3\lib\site-packages (from skypilot[aws,gcp]==0.5.0->inference) (0.5.0)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\covid\anaconda3\lib\site-packages (from inference) (6.0)
# Requirement already satisfied: tqdm>=4.0.0 in c:\users\covid\anaconda3\lib\site-packages (from inference) (4.64.1)
# Requirement already satisfied: py-cpuinfo>=9.0.0 in c:\users\covid\anaconda3\lib\site-packages (from inference) (9.0.0)
# Requirement already satisfied: aiohttp>=3.9.0 in c:\users\covid\anaconda3\lib\site-packages (from inference) (3.9.5)
# Requirement already satisfied: backoff>=2.2.0 in c:\users\covid\anaconda3\lib\site-packages (from inference) (2.2.1)
# Requirement already satisfied: dataclasses-json>=0.6.0 in c:\users\covid\anaconda3\lib\site-packages (from inference) (0.6.7)
# Requirement already satisfied: aioresponses>=0.7.6 in c:\users\covid\anaconda3\lib\site-packages (from inference) (0.7.6)
# Requirement already satisfied: packaging>=14.0 in c:\users\covid\anaconda3\lib\site-packages (from docker==6.1.3->inference) (22.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\covid\anaconda3\lib\site-packages (from docker==6.1.3->inference) (1.26.14)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\users\covid\anaconda3\lib\site-packages (from docker==6.1.3->inference) (0.58.0)
# Requirement already satisfied: pywin32>=304 in c:\users\covid\anaconda3\lib\site-packages (from docker==6.1.3->inference) (305.1)
# Requirement already satisfied: cachetools in c:\users\covid\anaconda3\lib\site-packages (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference) (5.3.1)
# Requirement already satisfied: click>=7.0 in c:\users\covid\anaconda3\lib\site-packages (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference) (8.0.4)
# Requirement already satisfied: colorama in c:\users\covid\anaconda3\lib\site-packages (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference) (0.4.4)
# Requirement already satisfied: cryptography in c:\users\covid\anaconda3\lib\site-packages (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference) (39.0.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\covid\anaconda3\lib\site-packages (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference) (3.1.2)
# Requirement already satisfied: jsonschema in c:\users\covid\anaconda3\lib\site-packages (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference) (4.17.3)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\covid\anaconda3\lib\site-packages (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference) (1.5.3)
# Requirement already satisfied: pendulum in c:\users\covid\anaconda3\lib\site-packages (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference) (3.0.0)
# Requirement already satisfied: PrettyTable>=2.0.0 in c:\users\covid\anaconda3\lib\site-packages (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference) (3.10.0)
# Requirement already satisfied: tabulate in c:\users\covid\anaconda3\lib\site-packages (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference) (0.8.10)
# Requirement already satisfied: filelock>=3.6.0 in c:\users\covid\anaconda3\lib\site-packages (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference) (3.9.0)
# Requirement already satisfied: psutil in c:\users\covid\anaconda3\lib\site-packages (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference) (5.9.0)
# Requirement already satisfied: pulp in c:\users\covid\anaconda3\lib\site-packages (from skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference) (2.8.0)
# Requirement already satisfied: google-api-python-client>=2.69.0 in c:\users\covid\anaconda3\lib\site-packages (from skypilot[aws,gcp]==0.5.0->inference) (2.88.0)
# Requirement already satisfied: google-cloud-storage in c:\users\covid\anaconda3\lib\site-packages (from skypilot[aws,gcp]==0.5.0->inference) (2.17.0)
# Requirement already satisfied: awscli>=1.27.10 in c:\users\covid\anaconda3\lib\site-packages (from skypilot[aws,gcp]==0.5.0->inference) (1.33.21)
# Requirement already satisfied: botocore>=1.29.10 in c:\users\covid\anaconda3\lib\site-packages (from skypilot[aws,gcp]==0.5.0->inference) (1.34.139)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\covid\anaconda3\lib\site-packages (from aiohttp>=3.9.0->inference) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\covid\anaconda3\lib\site-packages (from aiohttp>=3.9.0->inference) (22.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\covid\anaconda3\lib\site-packages (from aiohttp>=3.9.0->inference) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\covid\anaconda3\lib\site-packages (from aiohttp>=3.9.0->inference) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\covid\anaconda3\lib\site-packages (from aiohttp>=3.9.0->inference) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\covid\anaconda3\lib\site-packages (from aiohttp>=3.9.0->inference) (4.0.3)
# Requirement already satisfied: six>=1.4.0 in c:\users\covid\anaconda3\lib\site-packages (from APScheduler<=3.10.1->inference) (1.16.0)
# Requirement already satisfied: pytz in c:\users\covid\anaconda3\lib\site-packages (from APScheduler<=3.10.1->inference) (2022.7)
# Requirement already satisfied: tzlocal!=3.*,>=2.0 in c:\users\covid\anaconda3\lib\site-packages (from APScheduler<=3.10.1->inference) (5.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\covid\anaconda3\lib\site-packages (from boto3<=1.34.123->inference) (0.10.0)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in c:\users\covid\anaconda3\lib\site-packages (from boto3<=1.34.123->inference) (0.10.2)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\covid\anaconda3\lib\site-packages (from dataclasses-json>=0.6.0->inference) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\covid\anaconda3\lib\site-packages (from dataclasses-json>=0.6.0->inference) (0.9.0)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in c:\users\covid\anaconda3\lib\site-packages (from fastapi<0.111,>=0.100->inference) (0.37.2)
# Requirement already satisfied: coloredlogs in c:\users\covid\anaconda3\lib\site-packages (from onnxruntime<=1.15.1->inference) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\covid\anaconda3\lib\site-packages (from onnxruntime<=1.15.1->inference) (23.5.26)
# Requirement already satisfied: protobuf in c:\users\covid\anaconda3\lib\site-packages (from onnxruntime<=1.15.1->inference) (4.25.3)
# Requirement already satisfied: sympy in c:\users\covid\anaconda3\lib\site-packages (from onnxruntime<=1.15.1->inference) (1.11.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\covid\anaconda3\lib\site-packages (from openai>=1.12.0->inference) (3.5.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\covid\anaconda3\lib\site-packages (from openai>=1.12.0->inference) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\covid\anaconda3\lib\site-packages (from openai>=1.12.0->inference) (0.27.0)
# Requirement already satisfied: sniffio in c:\users\covid\anaconda3\lib\site-packages (from openai>=1.12.0->inference) (1.2.0)
# Requirement already satisfied: prometheus-client<1.0.0,>=0.8.0 in c:\users\covid\anaconda3\lib\site-packages (from prometheus-fastapi-instrumentator<=6.0.0->inference) (0.14.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\covid\anaconda3\lib\site-packages (from pydantic~=2.6->inference) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\covid\anaconda3\lib\site-packages (from pydantic~=2.6->inference) (2.20.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\covid\anaconda3\lib\site-packages (from pydot>=2.0.0->inference) (3.0.9)
# Requirement already satisfied: pytest>=7.0.0 in c:\users\covid\anaconda3\lib\site-packages (from pytest-asyncio<=0.21.1->inference) (7.1.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\covid\anaconda3\lib\site-packages (from requests>=2.26.0->inference) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\covid\anaconda3\lib\site-packages (from requests>=2.26.0->inference) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\covid\anaconda3\lib\site-packages (from requests>=2.26.0->inference) (2023.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\covid\anaconda3\lib\site-packages (from rich<=13.5.2->inference) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\covid\anaconda3\lib\site-packages (from rich<=13.5.2->inference) (2.18.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\covid\anaconda3\lib\site-packages (from scikit-image>=0.19.0->inference) (1.10.0)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\covid\anaconda3\lib\site-packages (from scikit-image>=0.19.0->inference) (2.26.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\covid\anaconda3\lib\site-packages (from scikit-image>=0.19.0->inference) (2021.7.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\covid\anaconda3\lib\site-packages (from scikit-image>=0.19.0->inference) (1.4.1)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in c:\users\covid\anaconda3\lib\site-packages (from supervision<1.0.0,>=0.20.0->inference) (0.7.1)
# Requirement already satisfied: matplotlib>=3.6.0 in c:\users\covid\anaconda3\lib\site-packages (from supervision<1.0.0,>=0.20.0->inference) (3.7.0)
# Requirement already satisfied: opencv-python-headless>=4.5.5.64 in c:\users\covid\anaconda3\lib\site-packages (from supervision<1.0.0,>=0.20.0->inference) (4.10.0.84)
# Requirement already satisfied: docutils<0.17,>=0.10 in c:\users\covid\anaconda3\lib\site-packages (from awscli>=1.27.10->skypilot[aws,gcp]==0.5.0->inference) (0.16)
# Requirement already satisfied: rsa<4.8,>=3.1.2 in c:\users\covid\anaconda3\lib\site-packages (from awscli>=1.27.10->skypilot[aws,gcp]==0.5.0->inference) (4.7.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\covid\anaconda3\lib\site-packages (from botocore>=1.29.10->skypilot[aws,gcp]==0.5.0->inference) (2.8.2)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in c:\users\covid\anaconda3\lib\site-packages (from google-api-python-client>=2.69.0->skypilot[aws,gcp]==0.5.0->inference) (0.22.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in c:\users\covid\anaconda3\lib\site-packages (from google-api-python-client>=2.69.0->skypilot[aws,gcp]==0.5.0->inference) (2.31.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in c:\users\covid\anaconda3\lib\site-packages (from google-api-python-client>=2.69.0->skypilot[aws,gcp]==0.5.0->inference) (0.1.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in c:\users\covid\anaconda3\lib\site-packages (from google-api-python-client>=2.69.0->skypilot[aws,gcp]==0.5.0->inference) (2.19.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\covid\anaconda3\lib\site-packages (from google-api-python-client>=2.69.0->skypilot[aws,gcp]==0.5.0->inference) (4.1.1)
# Requirement already satisfied: httpcore==1.* in c:\users\covid\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai>=1.12.0->inference) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\covid\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.12.0->inference) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\covid\anaconda3\lib\site-packages (from jinja2>=3.0->skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference) (2.1.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\covid\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich<=13.5.2->inference) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\covid\anaconda3\lib\site-packages (from matplotlib>=3.6.0->supervision<1.0.0,>=0.20.0->inference) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\covid\anaconda3\lib\site-packages (from matplotlib>=3.6.0->supervision<1.0.0,>=0.20.0->inference) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\covid\anaconda3\lib\site-packages (from matplotlib>=3.6.0->supervision<1.0.0,>=0.20.0->inference) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\covid\anaconda3\lib\site-packages (from matplotlib>=3.6.0->supervision<1.0.0,>=0.20.0->inference) (1.4.4)
# Requirement already satisfied: wcwidth in c:\users\covid\anaconda3\lib\site-packages (from PrettyTable>=2.0.0->skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference) (0.2.5)
# Requirement already satisfied: iniconfig in c:\users\covid\anaconda3\lib\site-packages (from pytest>=7.0.0->pytest-asyncio<=0.21.1->inference) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\covid\anaconda3\lib\site-packages (from pytest>=7.0.0->pytest-asyncio<=0.21.1->inference) (1.0.0)
# Requirement already satisfied: py>=1.8.2 in c:\users\covid\anaconda3\lib\site-packages (from pytest>=7.0.0->pytest-asyncio<=0.21.1->inference) (1.11.0)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\covid\anaconda3\lib\site-packages (from pytest>=7.0.0->pytest-asyncio<=0.21.1->inference) (2.0.1)
# Requirement already satisfied: atomicwrites>=1.0 in c:\users\covid\anaconda3\lib\site-packages (from pytest>=7.0.0->pytest-asyncio<=0.21.1->inference) (1.4.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\covid\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json>=0.6.0->inference) (0.4.3)
# Requirement already satisfied: tzdata in c:\users\covid\anaconda3\lib\site-packages (from tzlocal!=3.*,>=2.0->APScheduler<=3.10.1->inference) (2024.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\covid\anaconda3\lib\site-packages (from coloredlogs->onnxruntime<=1.15.1->inference) (10.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\covid\anaconda3\lib\site-packages (from cryptography->skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference) (1.15.1)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in c:\users\covid\anaconda3\lib\site-packages (from google-cloud-storage->skypilot[aws,gcp]==0.5.0->inference) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.6.0 in c:\users\covid\anaconda3\lib\site-packages (from google-cloud-storage->skypilot[aws,gcp]==0.5.0->inference) (2.7.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\covid\anaconda3\lib\site-packages (from google-cloud-storage->skypilot[aws,gcp]==0.5.0->inference) (1.5.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\covid\anaconda3\lib\site-packages (from jsonschema->skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference) (0.18.0)
# Requirement already satisfied: time-machine>=2.6.0 in c:\users\covid\anaconda3\lib\site-packages (from pendulum->skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference) (2.14.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\covid\anaconda3\lib\site-packages (from sympy->onnxruntime<=1.15.1->inference) (1.2.1)
# Requirement already satisfied: pycparser in c:\users\covid\anaconda3\lib\site-packages (from cffi>=1.12->cryptography->skypilot==0.5.0->skypilot[aws,gcp]==0.5.0->inference) (2.21)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\covid\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=2.69.0->skypilot[aws,gcp]==0.5.0->inference) (1.59.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\covid\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=2.69.0->skypilot[aws,gcp]==0.5.0->inference) (1.24.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\covid\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=2.69.0->skypilot[aws,gcp]==0.5.0->inference) (0.2.8)
# Requirement already satisfied: pyreadline3 in c:\users\covid\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime<=1.15.1->inference) (3.4.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\covid\anaconda3\lib\site-packages (from rsa<4.8,>=3.1.2->awscli>=1.27.10->skypilot[aws,gcp]==0.5.0->inference) (0.4.8)
# [notice] A new release of pip is available: 23.3.1 -> 24.1.1
# [notice] To update, run: C:\Users\covid\anaconda3\python.exe -m pip install --upgrade pip

# %%
import inference
model = inference.get_model("oriented-books/1")
model.infer(image="YOUR_IMAGE.jpg")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 import inference
#       2 model = inference.get_model("oriented-books/1")
#       3 model.infer(image="YOUR_IMAGE.jpg")
#
# ModuleNotFoundError: No module named 'inference'

# %%
# !C:\Users\covid\anaconda3\python.exe -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\covid\anaconda3\lib\site-packages (23.3.1)
# Collecting pip
#   Downloading pip-24.1.1-py3-none-any.whl.metadata (3.6 kB)
# Downloading pip-24.1.1-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    --------- ------------------------------ 0.4/1.8 MB 8.9 MB/s eta 0:00:01
#    --------------------------- ------------ 1.3/1.8 MB 16.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 16.6 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.3.1
#     Uninstalling pip-23.3.1:
#       Successfully uninstalled pip-23.3.1
# Successfully installed pip-24.1.1

# %%
# !pip3 install roboflow
# Out:
# Requirement already satisfied: roboflow in c:\users\covid\anaconda3\lib\site-packages (1.1.34)
# Requirement already satisfied: certifi in c:\users\covid\anaconda3\lib\site-packages (from roboflow) (2023.7.22)
# Requirement already satisfied: chardet==4.0.0 in c:\users\covid\anaconda3\lib\site-packages (from roboflow) (4.0.0)
# Requirement already satisfied: idna==3.7 in c:\users\covid\anaconda3\lib\site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in c:\users\covid\anaconda3\lib\site-packages (from roboflow) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\covid\anaconda3\lib\site-packages (from roboflow) (1.4.4)
# Requirement already satisfied: matplotlib in c:\users\covid\anaconda3\lib\site-packages (from roboflow) (3.7.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\covid\anaconda3\lib\site-packages (from roboflow) (1.23.5)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in c:\users\covid\anaconda3\lib\site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\covid\anaconda3\lib\site-packages (from roboflow) (9.4.0)
# Requirement already satisfied: python-dateutil in c:\users\covid\anaconda3\lib\site-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in c:\users\covid\anaconda3\lib\site-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in c:\users\covid\anaconda3\lib\site-packages (from roboflow) (2.28.1)
# Requirement already satisfied: six in c:\users\covid\anaconda3\lib\site-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in c:\users\covid\anaconda3\lib\site-packages (from roboflow) (1.26.14)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\covid\anaconda3\lib\site-packages (from roboflow) (4.64.1)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\covid\anaconda3\lib\site-packages (from roboflow) (6.0)
# Requirement already satisfied: requests-toolbelt in c:\users\covid\anaconda3\lib\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: python-magic in c:\users\covid\anaconda3\lib\site-packages (from roboflow) (0.4.27)
# Requirement already satisfied: colorama in c:\users\covid\anaconda3\lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\covid\anaconda3\lib\site-packages (from matplotlib->roboflow) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\covid\anaconda3\lib\site-packages (from matplotlib->roboflow) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\covid\anaconda3\lib\site-packages (from matplotlib->roboflow) (22.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\covid\anaconda3\lib\site-packages (from matplotlib->roboflow) (3.0.9)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\covid\anaconda3\lib\site-packages (from requests->roboflow) (2.0.4)

# %%
# !pip3 show roboflow
# Out:
# Name: roboflow
# Version: 1.1.34
# Summary: Official Python package for working with the Roboflow API
# Home-page: https://github.com/roboflow-ai/roboflow-python
# Author: Roboflow
# Author-email: support@roboflow.com
# License: UNKNOWN
# Location: c:\users\covid\anaconda3\lib\site-packages
# Requires: certifi, chardet, cycler, idna, kiwisolver, matplotlib, numpy, opencv-python-headless, Pillow, python-dateutil, python-dotenv, python-magic, PyYAML, requests, requests-toolbelt, six, tqdm, urllib3
# Required-by:

# %%
from roboflow import roboflow

rf = Roboflow(api_key="9RdognCaI8Nuh4bFkYHc")
project = rf.workspace("koteitan").project("oriented-books")
version = project.version(1)
dataset = version.download("yolov7")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 from roboflow import roboflow
#       3 rf = Roboflow(api_key="9RdognCaI8Nuh4bFkYHc")
#       4 project = rf.workspace("koteitan").project("oriented-books")
#
# ModuleNotFoundError: No module named 'roboflow'

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="9RdognCaI8Nuh4bFkYHc")
project = rf.workspace("koteitan").project("oriented-books")
version = project.version(1)
dataset = version.download("yolov7")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 from roboflow import Roboflow
#       2 rf = Roboflow(api_key="9RdognCaI8Nuh4bFkYHc")
#       3 project = rf.workspace("koteitan").project("oriented-books")
#
# ModuleNotFoundError: No module named 'roboflow'

# %%
# import the inference-sdk
from inference_sdk import InferenceHTTPClient

# initialize the client
CLIENT = InferenceHTTPClient(
    api_url="https://detect.roboflow.com",
    api_key="9RdognCaI8Nuh4bFkYHc"
)

# infer on a local image
result = CLIENT.infer("YOUR_IMAGE.jpg", model_id="oriented-books/1")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 2
#       1 # import the inference-sdk
# ----> 2 from inference_sdk import InferenceHTTPClient
#       4 # initialize the client
#       5 CLIENT = InferenceHTTPClient(
#       6     api_url="https://detect.roboflow.com",
#       7     api_key="9RdognCaI8Nuh4bFkYHc"
#       8 )
#
# ModuleNotFoundError: No module named 'inference_sdk'

# %% [markdown]
# ## Execution

# %%
#Variable list
# ディレクトリのパス
directory_path = "C:/Users/covid/text_recognition/yolov7/runs/detect"
# 画像ファイルの相対パスを指定
image_relative_path = "input.png"
# テキストファイルの相対パスを指定
text_file_relative_path = "labels/input.txt"

out_path = 'C:/Users/covid/text_recognition/output'
output_file = "C:/Users/covid/text_recognition/output_results.txt"

# %%
#import time

#time.sleep(15)

# %%
cap = cv2.VideoCapture(0)

ret, frame = cap.read()
cv2.imwrite("C:/Users/covid/text_recognition/yolov7/input.png",frame)

cap.release()

# %%
cd "C:\Users\covid\text_recognition\yolov7"
# Out:
# C:\Users\covid\text_recognition\yolov7

# %%
# ディレクトリ内のサブディレクトリのリストを取得
subdirectories = [d for d in os.listdir(directory_path) if os.path.isdir(os.path.join(directory_path, d))]

# サブディレクトリの中で一番新しいものを取得
newest_subdirectory = max(subdirectories, key=lambda d: os.path.getctime(os.path.join(directory_path, d)))

# 最新のサブディレクトリのパスを作成
newest_subdirectory_path = os.path.join(directory_path, newest_subdirectory)

# %%
# !python detect.py --source C:/Users/covid/text_recognition/yolov7/input.png --weights yolov7-e6e.pt --conf 0.25 --img-size 1280 --device 0 --save-txt
# Out:
# Namespace(weights=['yolov7-e6e.pt'], source='C:/Users/covid/text_recognition/yolov7/input.png', img_size=1280, conf_thres=0.25, iou_thres=0.45, device='0', view_img=False, save_txt=True, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# Fusing layers...
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# 9 books, Done. (27.0ms) Inference, (47.1ms) NMS
#  The image with the result is saved in: runs\detect\exp68\input.png
# Done. (0.442s)
# YOLOR  v0.1-126-g84932d7 torch 2.1.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3090, 24575.5MB)
#
# Model Summary: 792 layers, 151687420 parameters, 817020 gradients
# C:\Users\covid\anaconda3\envs\localGPU\lib\site-packages\torch\functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ..\aten\src\ATen\native\TensorShape.cpp:3527.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
# ディレクトリ内のサブディレクトリのリストを取得
subdirectories = [d for d in os.listdir(directory_path) if os.path.isdir(os.path.join(directory_path, d))]

# サブディレクトリの中で一番新しいものを取得
newest_subdirectory = max(subdirectories, key=lambda d: os.path.getctime(os.path.join(directory_path, d)))

# 最新のサブディレクトリのパスを作成
newest_subdirectory_path = os.path.join(directory_path, newest_subdirectory)
# 新しいディレクトリに移動
os.chdir(newest_subdirectory_path)

# 画像ファイルの絶対パスを作成
image_absolute_path = os.path.join(newest_subdirectory_path, image_relative_path)
# テキストファイルの絶対パスを作成
text_file_absolute_path = os.path.join(newest_subdirectory_path, text_file_relative_path)

# %%
print()
print(image_absolute_path)
# Out:
# C:/Users/covid/text_recognition/yolov7/runs/detect\exp68\input.png

# %%
# 画像をImageクラスのインスタンスに読み込む
image = Image.open(image_absolute_path)
# テキストファイルを読み込む
with open(text_file_absolute_path, 'r') as file:
    text_content = file.read()

# %%
# Process the text file
wid,hei = image.size
process_text_file(text_file_absolute_path)

# %%
#output corresponding to list format
if __name__ == '__main__':
    output_list = []

    file_list = [filename for filename in os.listdir(out_path) if filename.endswith('.jpg')]
    file_list.sort(key=lambda x: int(''.join(filter(str.isdigit, x))))

    for filename in file_list:
        input_file = os.path.join(out_path, filename)
        output = read_ocr(service, input_file, 'ja')

        # 不要な文字（スペースとバックスラッシュ）を除去して一つの文字列に結合する
        cleaned_output = ''.join(line.strip().replace(' ', '').replace('/', '').replace('\n', '').replace('\\', '') for line in output)

        # 結果をリストに追加
        output_list.append(cleaned_output)

# %%
# Save the results to the output file
with open(output_file, 'w', encoding='utf-8') as file:
        for result in output_list:
            file.write(result + '\n')

print(f"Results saved to {output_file}")
# Out:
# Results saved to C:/Users/covid/text_recognition/output_results.txt

# %% [markdown]
# ## Compare NLP Methods

# %% [markdown]
# ### Different.SequenceMatcher

# %%
cd "C:\\Users\\covid\\text_recognition"
# Out:
# C:\Users\covid\text_recognition

# %%
import difflib

def main():
    file_a_path = "output_results.txt"
    file_b_path = "database.txt"

    with open(file_a_path, "r", encoding="utf-8") as file_a:
        lines_a = file_a.readlines()

    with open(file_b_path, "r", encoding="utf-8") as file_b:
        lines_b = file_b.readlines()

    for index_a, text_a in enumerate(lines_a):
        max_similarity = 0.0
        best_match = None
        best_match_text_b = None

        for index_b, text_b in enumerate(lines_b):
            similarity = difflib.SequenceMatcher(None, text_a, text_b).ratio()

            if similarity > max_similarity:
                max_similarity = similarity
                best_match = text_b
                best_match_text_b = text_b

        print(f"Text A (line {index_a + 1}): {text_a.strip()}")
        print(f"Best Match in Text B (line {lines_b.index(best_match) + 1}): {best_match.strip()}")
        print(f"Highest Similarity Ratio: {max_similarity:.4f}\n")

if __name__ == "__main__":
    main()
# Out:
# Text A (line 1): 新明解C言語入門編柴田
# Best Match in Text B (line 31): 新・明解C言語入門編柴田望洋SBCreative
# Highest Similarity Ratio: 0.6486
#
# Text A (line 2): 解きながら学ぶC言明解きながら学ぶC言語柴田望
# Best Match in Text B (line 32): 解きながら学ぶC言語柴田望洋[監修・著]赤尾浩・肘井信一・高木宏典[著]SBCreative
# Highest Similarity Ratio: 0.3944
#
# Text A (line 3): プログラミングROSPythonによるロボットアプリケーション開発MorganQuigleyBrianGerkeyWilliamD.Smart
# Best Match in Text B (line 35): プログラミングROSPythonによるロボットアプリケーション開発MorganQuigleyBrianGerkeyWilliamD.Smart河田卓志監訳松田晃一、福地正樹、由谷哲夫訳O'REILLY
# Highest Similarity Ratio: 0.8324
#
# Text A (line 4): KINECTforWindowsSDKプログラミングC++編
# Best Match in Text B (line 41): KINECTforWindowsSDKプログラミングC++編株式会社ゲッシュ中村薰齋藤俊太宮城英人〈著>システム
# Highest Similarity Ratio: 0.7045
#
# Text A (line 5): C++111410刷
# Best Match in Text B (line 51): C++1114コア言語10刷突破!C++入門書のロングセラー!!~.マイナビ
# Highest Similarity Ratio: 0.4400
#
# Text A (line 6): CUDACCUDAの機能・手法をプロフェッショナルプログラミング網羅的に解説!
# Best Match in Text B (line 73): CUDACプロフェッショナルプログラミングCUDAの機能・手法を網羅的に解説!
# Highest Similarity Ratio: 0.7250
#
# Text A (line 7): HOTELE言語実装パターンコンパイラ技術によるテキスト処理か言語実装までらTem
# Best Match in Text B (line 74): 言語実装パターンコンパイラ技術によるテキスト処理から言語実装までTerence Parr著中田育男監訳伊藤真浩訳O'Reilly
# Highest Similarity Ratio: 0.6355
#
# Text A (line 8): 詳解OpenCV3コンピュータビジョンライブラリを使った画像処理・認識永松G
# Best Match in Text B (line 52): 詳解OpenCV3AdrianKaehlerGaryBradski松田晃一、小沼千絵著永田雅人、花形理訳O'REILLY
# Highest Similarity Ratio: 0.2200
#
# Text A (line 9): リスク評価と危機管理ネットワークバ
# Best Match in Text B (line 53): 実践ネットワークセキュリティ監査リスク評価と危機管理ChrisMcNab著鍋島公章監訳(株)ネットワークバリューコンポネンツ訳O'REILLY
# Highest Similarity Ratio: 0.4000

# %%
def main():
    file_a_path = "output_results.txt"
    file_b_path = "database.txt"
    output_file = "output_similarity.txt"

    with open(file_a_path, "r", encoding="utf-8") as file_a:
        lines_a = file_a.readlines()

    with open(file_b_path, "r", encoding="utf-8") as file_b:
        lines_b = file_b.readlines()

    with open(output_file, "w", encoding="utf-8") as output:
        for index_a, text_a in enumerate(lines_a):
            for index_b, text_b in enumerate(lines_b):
                similarity = difflib.SequenceMatcher(None, text_a, text_b).ratio()

                output.write(f"Text A (line {index_a + 1}): {text_a.strip()}\n")
                output.write(f"Text B (line {index_b + 1}): {text_b.strip()}\n")
                output.write(f"Similarity Ratio: {similarity:.4f}\n\n")

if __name__ == "__main__":
    main()

# %% [markdown]
# ### Levenshtein distance

# %%
import Levenshtein

def main():
    file_a_path = "output_results.txt"
    file_b_path = "database.txt"

    with open(file_a_path, "r", encoding="utf-8") as file_a:
        lines_a = file_a.readlines()

    with open(file_b_path, "r", encoding="utf-8") as file_b:
        lines_b = file_b.readlines()

    for index_a, text_a in enumerate(lines_a):
        max_similarity = 0.0
        best_match = None

        for index_b, text_b in enumerate(lines_b):
            similarity = Levenshtein.ratio(text_a.strip(), text_b.strip())

            if similarity > max_similarity:
                max_similarity = similarity
                best_match = text_b

        print(f"Original Text A (line {index_a + 1}): {text_a.strip()}")
        print(f"Best Match for Text A (line {index_a + 1}): {best_match.strip()}")
        print(f"Highest Similarity Ratio: {max_similarity:.4f}\n")

if __name__ == "__main__":
    main()
# Out:
# Original Text A (line 1): 新明解C言語入門編柴田
# Best Match for Text A (line 1): 新・明解C言語入門編柴田望洋SBCreative
# Highest Similarity Ratio: 0.6286
#
# Original Text A (line 2): 解きながら学ぶC言明解きながら学ぶC言語柴田望
# Best Match for Text A (line 2): 解きながら学ぶC言語柴田望洋[監修・著]赤尾浩・肘井信一・高木宏典[著]SBCreative
# Highest Similarity Ratio: 0.3768
#
# Original Text A (line 3): プログラミングROSPythonによるロボットアプリケーション開発MorganQuigleyBrianGerkeyWilliamD.Smart
# Best Match for Text A (line 3): プログラミングROSPythonによるロボットアプリケーション開発MorganQuigleyBrianGerkeyWilliamD.Smart河田卓志監訳松田晃一、福地正樹、由谷哲夫訳O'REILLY
# Highest Similarity Ratio: 0.8304
#
# Original Text A (line 4): KINECTforWindowsSDKプログラミングC++編
# Best Match for Text A (line 4): KINECTforWindowsSDKプログラミングC++編株式会社ゲッシュ中村薰齋藤俊太宮城英人〈著>システム
# Highest Similarity Ratio: 0.6977
#
# Original Text A (line 5): C++111410刷
# Best Match for Text A (line 5): C++1114コア言語10刷突破!C++入門書のロングセラー!!~.マイナビ
# Highest Similarity Ratio: 0.4167
#
# Original Text A (line 6): CUDACCUDAの機能・手法をプロフェッショナルプログラミング網羅的に解説!
# Best Match for Text A (line 6): CUDACプロフェッショナルプログラミングCUDAの機能・手法を網羅的に解説!
# Highest Similarity Ratio: 0.7179
#
# Original Text A (line 7): HOTELE言語実装パターンコンパイラ技術によるテキスト処理か言語実装までらTem
# Best Match for Text A (line 7): 言語実装パターンコンパイラ技術によるテキスト処理から言語実装までTerence Parr著中田育男監訳伊藤真浩訳O'Reilly
# Highest Similarity Ratio: 0.6286
#
# Original Text A (line 8): 詳解OpenCV3コンピュータビジョンライブラリを使った画像処理・認識永松G
# Best Match for Text A (line 8): 詳解OpenCV3AdrianKaehlerGaryBradski松田晃一、小沼千絵著永田雅人、花形理訳O'REILLY
# Highest Similarity Ratio: 0.2041
#
# Original Text A (line 9): リスク評価と危機管理ネットワークバ
# Best Match for Text A (line 9): 実践ネットワークセキュリティ監査リスク評価と危機管理ChrisMcNab著鍋島公章監訳(株)ネットワークバリューコンポネンツ訳O'REILLY
# Highest Similarity Ratio: 0.3864

# %%
def main():
    file_a_path = "output_results.txt"
    file_b_path = "database.txt"
    output_file = "levenshtein_similarity.txt"

    with open(file_a_path, "r", encoding="utf-8") as file_a:
        lines_a = file_a.readlines()

    with open(file_b_path, "r", encoding="utf-8") as file_b:
        lines_b = file_b.readlines()

    with open(output_file, "w", encoding="utf-8") as output:
        for index_a, text_a in enumerate(lines_a):
            max_similarity = 0.0
            best_match = None

            for index_b, text_b in enumerate(lines_b):
                similarity = Levenshtein.ratio(text_a.strip(), text_b.strip())

                output.write(f"Text A (line {index_a + 1}): {text_a.strip()}\n")
                output.write(f"Text B (line {index_b + 1}): {text_b.strip()}\n")
                output.write(f"Similarity Ratio: {similarity:.4f}\n\n")

                if similarity > max_similarity:
                    max_similarity = similarity
                    best_match = text_b

            output.write(f"Best Match for Text A (line {index_a + 1}): {best_match.strip()}\n")
            output.write(f"Highest Similarity Ratio: {max_similarity:.4f}\n\n")

if __name__ == "__main__":
    main()

# %% [markdown]
# ### Jaccard

# %%
def jaccard_coefficient(s1, s2):
    set1 = set(s1)
    set2 = set(s2)
    intersection = len(set1 & set2)
    union = len(set1 | set2)
    return intersection / union if union > 0 else 0.0

def main():
    file_a_path = "output_results.txt"
    file_b_path = "database.txt"

    with open(file_a_path, "r", encoding="utf-8") as file_a:
        lines_a = file_a.readlines()

    with open(file_b_path, "r", encoding="utf-8") as file_b:
        lines_b = file_b.readlines()

    for index_a, text_a in enumerate(lines_a):
        max_similarity = 0.0
        best_match = None

        for index_b, text_b in enumerate(lines_b):
            similarity = jaccard_coefficient(text_a.strip(), text_b.strip())

            if similarity > max_similarity:
                max_similarity = similarity
                best_match = text_b

        print(f"Original Text A (line {index_a + 1}): {text_a.strip()}")
        print(f"Best Match for Text A (line {index_a + 1}): {best_match.strip()}")
        print(f"Highest Jaccard Coefficient: {max_similarity:.4f}\n")

if __name__ == "__main__":
    main()
# Out:
# Original Text A (line 1): 新明解C言語入門編柴田
# Best Match for Text A (line 1): 新・明解C言語入門編柴田望洋SBCreative
# Highest Jaccard Coefficient: 0.5000
#
# Original Text A (line 2): 解きながら学ぶC言明解きながら学ぶC言語柴田望
# Best Match for Text A (line 2): 解きながら学ぶC言語柴田望洋[監修・著]赤尾浩・肘井信一・高木宏典[著]SBCreative
# Highest Jaccard Coefficient: 0.3250
#
# Original Text A (line 3): プログラミングROSPythonによるロボットアプリケーション開発MorganQuigleyBrianGerkeyWilliamD.Smart
# Best Match for Text A (line 3): プログラミングROSPythonによるロボットアプリケーション開発MorganQuigleyBrianGerkeyWilliamD.Smart河田卓志監訳松田晃一、福地正樹、由谷哲夫訳O'REILLY
# Highest Jaccard Coefficient: 0.6618
#
# Original Text A (line 4): KINECTforWindowsSDKプログラミングC++編
# Best Match for Text A (line 4): KINECTforWindowsSDKプログラミングC++編株式会社ゲッシュ中村薰齋藤俊太宮城英人〈著>システム
# Highest Jaccard Coefficient: 0.5000
#
# Original Text A (line 5): C++111410刷
# Best Match for Text A (line 5): C++1114コア言語10刷突破!C++入門書のロングセラー!!~.マイナビ
# Highest Jaccard Coefficient: 0.2069
#
# Original Text A (line 6): CUDACCUDAの機能・手法をプロフェッショナルプログラミング網羅的に解説!
# Best Match for Text A (line 6): CUDACプロフェッショナルプログラミングCUDAの機能・手法を網羅的に解説!
# Highest Jaccard Coefficient: 1.0000
#
# Original Text A (line 7): HOTELE言語実装パターンコンパイラ技術によるテキスト処理か言語実装までらTem
# Best Match for Text A (line 7): 言語実装パターンコンパイラ技術によるテキスト処理から言語実装までTerence Parr著中田育男監訳伊藤真浩訳O'Reilly
# Highest Jaccard Coefficient: 0.5273
#
# Original Text A (line 8): 詳解OpenCV3コンピュータビジョンライブラリを使った画像処理・認識永松G
# Best Match for Text A (line 8): 詳解OpenCV3AdrianKaehlerGaryBradski松田晃一、小沼千絵著永田雅人、花形理訳O'REILLY
# Highest Jaccard Coefficient: 0.1912
#
# Original Text A (line 9): リスク評価と危機管理ネットワークバ
# Best Match for Text A (line 9): 実践ネットワークセキュリティ監査リスク評価と危機管理ChrisMcNab著鍋島公章監訳(株)ネットワークバリューコンポネンツ訳O'REILLY
# Highest Jaccard Coefficient: 0.2909

# %%
def main():
    file_a_path = "output_results.txt"
    file_b_path = "database.txt"
    output_file = "jaccard_similarity.txt"

    with open(file_a_path, "r", encoding="utf-8") as file_a:
        lines_a = file_a.readlines()

    with open(file_b_path, "r", encoding="utf-8") as file_b:
        lines_b = file_b.readlines()

    with open(output_file, "w", encoding="utf-8") as output:
        for index_a, text_a in enumerate(lines_a):
            for index_b, text_b in enumerate(lines_b):
                similarity = jaccard_coefficient(text_a.strip(), text_b.strip())

                output.write(f"Text A (line {index_a + 1}): {text_a.strip()}\n")
                output.write(f"Text B (line {index_b + 1}): {text_b.strip()}\n")
                output.write(f"Jaccard Coefficient: {similarity:.4f}\n\n")

if __name__ == "__main__":
    main()

# %%
def jaccard_coefficient(s1, s2):
    set1 = set(s1)
    set2 = set(s2)
    intersection = len(set1 & set2)
    union = len(set1 | set2)
    return intersection / union if union > 0 else 0.0

def main():
    file_a_path = "output_results.txt"
    file_b_path = "database.txt"

    with open(file_a_path, "r", encoding="utf-8") as file_a:
        lines_a = file_a.readlines()

    with open(file_b_path, "r", encoding="utf-8") as file_b:
        lines_b = file_b.readlines()

    for index_a, text_a in enumerate(lines_a):
        # 空白の行をスキップ
        if not text_a.strip():
            continue

        max_similarity = 0.0
        best_match = None

        for index_b, text_b in enumerate(lines_b):
            similarity = jaccard_coefficient(text_a.strip(), text_b.strip())

            if similarity > max_similarity:
                max_similarity = similarity
                best_match = text_b

        print(f"Original Text A (line {index_a + 1}): {text_a.strip()}")
        
        if best_match is not None:
            print(f"Best Match for Text A (line {index_a + 1}): {best_match.strip()}")
            print(f"Highest Jaccard Coefficient: {max_similarity:.4f}\n")
        else:
            print("No matching text found.\n")

if __name__ == "__main__":
    main()
# Out:
# Original Text A (line 1): 新明解C言語入門編柴田
# Best Match for Text A (line 1): 新・明解C言語入門編柴田望洋SBCreative
# Highest Jaccard Coefficient: 0.5000
#
# Original Text A (line 2): 解きながら学ぶC言明解きながら学ぶC言語柴田望
# Best Match for Text A (line 2): 解きながら学ぶC言語柴田望洋[監修・著]赤尾浩・肘井信一・高木宏典[著]SBCreative
# Highest Jaccard Coefficient: 0.3250
#
# Original Text A (line 3): プログラミングROSPythonによるロボットアプリケーション開発MorganQuigleyBrianGerkeyWilliamD.Smart
# Best Match for Text A (line 3): プログラミングROSPythonによるロボットアプリケーション開発MorganQuigleyBrianGerkeyWilliamD.Smart河田卓志監訳松田晃一、福地正樹、由谷哲夫訳O'REILLY
# Highest Jaccard Coefficient: 0.6618
#
# Original Text A (line 4): KINECTforWindowsSDKプログラミングC++編
# Best Match for Text A (line 4): KINECTforWindowsSDKプログラミングC++編株式会社ゲッシュ中村薰齋藤俊太宮城英人〈著>システム
# Highest Jaccard Coefficient: 0.5000
#
# Original Text A (line 5): C++111410刷
# Best Match for Text A (line 5): C++1114コア言語10刷突破!C++入門書のロングセラー!!~.マイナビ
# Highest Jaccard Coefficient: 0.2069
#
# Original Text A (line 6): CUDACCUDAの機能・手法をプロフェッショナルプログラミング網羅的に解説!
# Best Match for Text A (line 6): CUDACプロフェッショナルプログラミングCUDAの機能・手法を網羅的に解説!
# Highest Jaccard Coefficient: 1.0000
#
# Original Text A (line 7): HOTELE言語実装パターンコンパイラ技術によるテキスト処理か言語実装までらTem
# Best Match for Text A (line 7): 言語実装パターンコンパイラ技術によるテキスト処理から言語実装までTerence Parr著中田育男監訳伊藤真浩訳O'Reilly
# Highest Jaccard Coefficient: 0.5273
#
# Original Text A (line 8): 詳解OpenCV3コンピュータビジョンライブラリを使った画像処理・認識永松G
# Best Match for Text A (line 8): 詳解OpenCV3AdrianKaehlerGaryBradski松田晃一、小沼千絵著永田雅人、花形理訳O'REILLY
# Highest Jaccard Coefficient: 0.1912
#
# Original Text A (line 9): リスク評価と危機管理ネットワークバ
# Best Match for Text A (line 9): 実践ネットワークセキュリティ監査リスク評価と危機管理ChrisMcNab著鍋島公章監訳(株)ネットワークバリューコンポネンツ訳O'REILLY
# Highest Jaccard Coefficient: 0.2909
